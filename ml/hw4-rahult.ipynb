# %% [markdown]
# ---
#
#
# # **CS 5805, Homework 4, 100 points, 15% Credit**
# ##**Due before 11:59 PM Wednesday November 19, 2025**
# ---

# %% [markdown]
# **Instructions**:
#
# 1.   Honor code is enforced. This is an individual assignment. You should do your own work. Any evidence of copying will result in an immediate zero grade (0 point) and additional penalties/actions.
# 2.   Edits are only allowed at where 'TODO' tags exist. Edits made elsewhere will result in an immediate zero grade (0 point).
# 3.   Importing extra packages is forbidden. Any extra package import (including but not limited to numpy, scikit-learn, etc.) will result in an immediate zero grade (0 point).
# 4.   Please run each cell, including those that are collapsed, shown as `Show code`.
# 5.   Upon completion of this assignment, please download a '.ipynb' file through Taskbar > File > Download > .ipynb, then upload the file to Canvas.
#
# ### **IMPORTANT NOTE:** ###
#
#
# 1.   **Your submitted .ipynb file should contain all the outputs, including the figures, images and run results, for each section. Due to the time-intensive nature of this assignment, the course staff WILL NOT re-run your code and reproduce your results. You will be graded based on your submitted .ipynb file containing all the outputs, including the figures, images and run results.**
# 2.   **You are strongly encouraged to do the assignment in Google Colab environment (as opposed to your local resources), frequently saving your work as you proceed. Refer to the expected runtime information of each section. These runtimes are provided based on simulations ran on Google Colab environment.**

# %% [markdown]
# # **1. Overview and Objective**
# In this assignment, we will introduce the [Image Classification](https://cs231n.github.io/classification/) problem, which is the task of assigning an input image one label from a fixed set of categories. This is one of the core problems in Computer Vision that, despite its simplicity, has a large variety of practical applications.
#
# You will experiment with fully connected neural networks and convolutional neural networks, using the Keras open source package. Keras is one of the simplest deep learning packages that serves as a wrapper on top of TensorFlow.
#
# **Preliminary steps**: Familiarize yourself with [Keras](https://keras.io/). Click on [Guides](https://keras.io/guides/) and read the first two guides: "[The functional API](https://keras.io/guides/functional_api/)" and "[The Sequential Model](https://keras.io/guides/sequential_model/)".
# Download and install Keras on a machine with a GPU or use Google's Colaboratory environment, which allows you to run Keras code on a GPU in the cloud. Colab already has Keras pre-installed. To enable GPU/TPU acceleration, click on **Edit** tab, then select **Notebook settings** and select **GPU** or **TPU** for hardware acceleration. TPUs are usually faster.

# %%
# new lines

TF_USE_LEGACY_KERAS=True
import os
os.environ['TF_USE_LEGACY_KERAS'] = "1"

# %%
# libraries (do not import additional libraries)
import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.datasets import cifar10
import math
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical

# %% [markdown]
# For designing the Neural Networks, we set the following parameters, which will remain unchanged for the rest of the assignment.
#
# ---

# %%
# parameters for this script
batch_size = 32
num_classes = 10
epochs = 25

# %% [markdown]
# ## **2. Load the CIFAR10 dataset**

# %% [markdown]
# The **CIFAR10 dataset** is composed of of 50,000 *32x32* color training images and 10,000 test images, labeled over 10 categories. See more info at the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html). The image categories are:
#
#   **Label**	**Description**
#
# 0.  airplane
# 1.  automobile
# 2. 	bird
# 3.	cat
# 4. 	deer
# 5. 	dog
# 6.	frog
# 7. 	horse
# 8.	ship
# 9.	truck
#
# The `generate_data()` function imports the CIFAR10 dataset and returns the training set, validation set and test set.
#
# **Returns**
#
# Tuple of NumPy arrays: `x_train, y_train, x_validate, y_validate, x_test, y_test`.
#
# **x_train:** uint8 NumPy array of grayscale image data with shapes `(40000, 32, 32, 3)`, containing the training data. Pixel values range from 0 to 255.
#
# **y_train:** uint8 NumPy array of labels (integers in range 0-9) with shape `(40000, 1)` for the training data.
#
# **x_validate:** uint8 NumPy array of grayscale image data with shapes `(10000, 32, 32, 3)`, containing the test data. Pixel values range from 0 to 255.
#
# **y_validate:** uint8 NumPy array of labels (integers in range 0-9) with shape `(10000, 1)` for the test data.
#
# **x_test:** uint8 NumPy array of grayscale image data with shapes `(10000, 32, 32, 3)`, containing the test data. Pixel values range from 0 to 255.
#
# **y_test:** uint8 NumPy array of labels (integers in range 0-9) with shape `(10000, 1)` for the test data.

# %%
def generate_data():
  # Load the data, split between train and test sets:
  (x_train, y_train), (x_test, y_test) = cifar10.load_data()
  print('x_train shape:', x_train.shape)
  print(x_train.shape[0], 'train samples')
  print(x_test.shape[0], 'test samples')

  # Convert class vectors to binary class matrices.
  y_train = to_categorical(y_train, num_classes)
  y_test = to_categorical(y_test, num_classes)
  # normalize the data
  x_train = x_train.astype('float32')
  x_test = x_test.astype('float32')
  x_train /= 255
  x_test /= 255

  # partition training set into training and validation set
  x_validate = x_train[40000:,:]
  x_train = x_train[:40000,:]
  y_validate = y_train[40000:,:]
  y_train = y_train[:40000,:]

  return x_train, y_train, x_validate, y_validate, x_test, y_test

# %%
x_train, y_train, x_validate, y_validate, x_test, y_test = generate_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# # **3. Visualize the data [5 points]**
# To better understand the dataset, let's plot the first 25 images from the training set and display the class name below each image:

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    '''
    TO-DO: Write the code to print the i-th image from the training set. Make
    sure that each image doesn't contain numeric values along both axes. The
    output should show only the images and their labels.
    '''
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i])


    # The CIFAR labels happen to be arrays, which is why you need the extra index
    plt.xlabel(class_names[np.nonzero(y_train[i])[0][0]])
plt.show()

# %% [markdown]
# ## **4. The basic Convolutional Neural Network (CNN) architecture**
# We define a basic CNN here using the [Keras Sequential API](https://www.tensorflow.org/guide/keras/overview).
#
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels). If you are new to these dimensions, color_channels refers to (R,G,B). In this example, you will configure your CNN to process inputs of shape (32, 32, 3), which is the format of CIFAR images. You can do this by passing the argument input_shape to your first layer.
#
# Then, we define the convolutional base using a common pattern: a stack of [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D), [MaxPooling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) and [dropout](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) layers.
#
# The output of every Conv2D and MaxPooling2D layer is a 3D tensor of shape (height, width, channels). The width and height dimensions tend to shrink as you go deeper in the network. The number of output channels for each Conv2D layer is controlled by the first argument (e.g., 32 or 64). Typically, as the width and height shrink, you can afford (computationally) to add more output channels in each Conv2D layer.
#
# To complete the model, you will feed the last output tensor from the convolutional base (of shape (8, 8, 64)) into one or more Dense layers to perform classification. Dense layers take vectors as input (which are 1D), while the current output is a 3D tensor. First, you will flatten (or unroll) the 3D output to 1D, then add one or more Dense layers on top. CIFAR has 10 output classes, so you use a final Dense layer with 10 outputs.
#
# Note that we are using [RMSProp](https://keras.io/api/optimizers/rmsprop/) as the optimizer for learning the weights of the CNN. We supply the values of `learning_rate` and `decay` parameter to the RMSProp optimizer. Do not modify them.
#
# The loss function used here is [categorical crossentropy](https://peltarion.com/knowledge-center/documentation/modeling-view/build-an-ai-model/loss-functions/categorical-crossentropy) that is used in multi-class classification tasks. These are tasks where an example can only belong to one out of many possible categories, and the model must decide which one. Formally, it is designed to quantify the difference between two probability distributions. The categorical crossentropy loss function calculates the loss of an example by computing the following:
#
# $$Loss = - \sum_{i=1}^{output \; size} y_i . \log \hat y_i$$
#
#
# where the outputs are in the form of probability distributions
#
# `output prediction`
#
# $ {\bf \hat y} = [0.2\; \; 0.7 \; \; \hat y_i\; \;  0.1]$
#
# `target`
#
# ${\bf y} = [\;\;0\; \; \;\;\;1 \; \; y_i\; \; \; \; 0]$

# %%
def base_cnn():
  """
  Define a convolutional neural network using the Sequential model. This is the
  basic CNN that you will need to reuse for the remaining parts of the assignment.
  It would be good to familiarize yourself with the workings of this basic CNN.
  """
  model = Sequential()
  '''
  Add 2D convolution layers the perform spatial convolution over images. This
  layer creates a convolution kernel that is convolved with the layer input to
  produce a tensor of outputs. When using this layer as the first layer in a
  model, provide the keyword argument 'input_shape' (tuple of integers). Besides,
  the Conv2D function takes as input
  - filters: Integer, the dimensionality of the output space (i.e. the number of
   output filters in the convolution). We set it to 32.
  - kernel_size: An integer or tuple/list of 2 integers, specifying the height
   and width of the 2D convolution window. Can be a single integer to specify
   the same value for all spatial dimensions. We set it to (3, 3).

  Here, we create a stack of (CONV2D, Activation, CONV2D, Activation) layers with
  the ReLu activation function
  '''
  model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
  model.add(Activation('relu'))
  model.add(Conv2D(32, (3, 3), padding='same'))
  model.add(Activation('relu'))
  '''
  Perform MaxPooling operation for 2D spatial data. This downsamples the input
  along its spatial dimensions (height and width) by taking the maximum value
  over an input window of size 2X2 for each channel of the input.
  '''
  model.add(MaxPooling2D(pool_size=(2, 2)))
  '''
  Add a Dropout layer that  randomly sets input units to 0 with a frequency of
  'rate' at each step during training time, which helps prevent overfitting.
  Inputs not set to 0 are scaled up by 1/(1 - rate) such that the sum over all
  inputs is unchanged. We set the rate to 0.25 for Dropout.
  '''
  model.add(Dropout(0.25))
  '''
  Create another stack of (CONV2D, Activation, CONV2D, Activation) layers with
  the ReLu activation function. Set the 'filters' to 64.
  '''
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  '''
  Perfrom MaxPooling and Dropout similar to the one defined earlier.
  '''
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  '''
  The image is still in 3D. It needs be unrolled from 3D to 1D using the Flatten
  layer. Then add a Dense layers on top of it followed by ReLu activation and
  dropout of 0.5. This helps to create a fully-connected layer.
  '''
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  '''
  Create the output layer using the Dense layer with 'softmax' activation. The
  number of predicted output needs to be equal to 'num_classes'.
  '''
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
  '''
  Set the optimizer for doing mini-batch gradient descent. Here, we make use of
  the RMSprop optimizer that comes with Keras. We supply some default values for
  the parameters learning_rate and decay. Do not modify them.
  '''
  opt = keras.optimizers.RMSprop(learning_rate=0.0001, weight_decay=1e-6)
  '''
  Compile the model for training. Since this is a multi-class classification
  problem, we use the 'categorical_crossentropy' loss function and 'accuracy' as
  the desired performance metric.
  '''
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print(model.summary())

  return model

# %% [markdown]
# ## **5. Activation functions for CNN [20 points]**
#
# ### **a) Compare the activation fuctions ReLu and Sigmoid [10 points]**
#
# In this section, we see the effect of changing the activation functions in the above CNN architecture.
#
# Compare the accuracy achieved by **rectified linear** units and **sigmoid** units in the base CNN. Produce two graphs (one for training accuracy and one for validation accuracy) that each contain 2 curves (one for rectified linear units and another one for sigmoid units). The y-axis is the accuracy and the x-axis is the number of epochs. Train the neural networks for 25 epochs. Although 25 epochs is not sufficient to reach convergence, it is sufficient to see the trend. Save the following results in your Jupyter notebook:
#
#
# *   The two graphs for training and validation accuracy.
# *   For each activation function, print the test accuracy of the model that achieved the best validation accuracy among all epochs (i.e., one best test accuracy per activation function).

# %%
def base_cnn_activation(activation):
  """
  TO-DO: Copy the code from the base_cnn() function above and paste it here.
  This starter code sets the activation function to 'relu' by default. Modify
  the code so that it can work with an user-supplied activation functions instead
  of the default 'relu' activation. Do not change the 'softmax' activation. Refer
  to the simulation code below to understand the possible values that the input
  'activation' may take.
  """
  model = Sequential()

  # initial two sets of layers
  model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
  model.add(Activation(activation))
  model.add(Conv2D(32, (3, 3), padding='same'))
  model.add(Activation(activation))
  # max pooling
  model.add(MaxPooling2D(pool_size=(2, 2)))
  # dropout
  model.add(Dropout(0.25))
  '''
  another stack of (CONV2D, Activation, CONV2D, Activation).
  Set the 'filters' to 64.
  '''
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation(activation))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation(activation))
  '''
  MaxPooling and Dropout similar to the one defined earlier.
  '''
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  '''
  The image is still in 3D. It needs be unrolled from 3D to 1D using the Flatten
  layer. Then add a Dense layers on top of it followed by ReLu activation and
  dropout of 0.5. This helps to create a fully-connected layer.
  '''
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation(activation))
  model.add(Dropout(0.5))
  '''
  Create the output layer using the Dense layer with 'softmax' activation. The
  number of predicted output needs to be equal to 'num_classes'.
  '''
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
  '''
  Set the optimizer for doing mini-batch gradient descent. Here, we make use of
  the RMSprop optimizer that comes with Keras. We supply some default values for
  the parameters learning_rate and decay. Do not modify them.
  '''
  opt = keras.optimizers.legacy.RMSprop(learning_rate=0.0001, decay=1e-6)
  '''
  Compile the model for training. Since this is a multi-class classification
  problem, we use the 'categorical_crossentropy' loss function and 'accuracy' as
  the desired performance metric.
  '''
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print(model.summary())

  return model

# %% [markdown]
# ### Test code to simulate this scenario (**do not modify**)
#
#
# **Expected runtime on Google Colab:** 30-60 minutes with TPU/GPU resources.

# %%
# create a callback that will save the best model while training
history_activations = dict()

for activation in ['relu', 'sigmoid']:
  print('Training CNN with {} activation function'.format(activation))
  save_best_model = ModelCheckpoint('best_model.{}'.format(activation), monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
  model =  base_cnn_activation(activation)
  history_activations[activation] = model.fit(x_train, y_train,
                                              batch_size=batch_size,
                                              epochs=epochs,
                                              validation_data=(x_validate, y_validate),
                                              shuffle=True,
                                              callbacks=[save_best_model])
# Plot training accuracy
for activation in ['relu', 'sigmoid']:
  plt.plot(history_activations[activation].history['accuracy'], 'o-', label='CNN + {} activation'.format(activation))

plt.title('training accuracy')
plt.ylabel('training accuracy')
plt.xlabel('epoch')
plt.legend(loc='lower right')
plt.show()

# Plot validation accuracy
for activation in ['relu', 'sigmoid']:
  plt.plot(history_activations[activation].history['val_accuracy'], 'o-', label='CNN + {} activation'.format(activation))
plt.title('validation accuracy')
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.legend(loc='lower right')
plt.show()

# Evaluate the best model saved (i.e., model with best validation accuracy) on the test set
for activation in ['relu','sigmoid']:
  saved_model = load_model('best_model.{}'.format(activation))
  scores = saved_model.evaluate(x_test, y_test, verbose=1)
  print('Test accuracy for {} activation: {}'.format(activation, scores[1]))
# Out:
# Training CNN with relu activation function
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_6 (Activation)   (None, 32, 32, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_7 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_8 (Activation)   (None, 16, 16, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_9 (Activation)   (None, 16, 16, 64)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 512)               2097664
#
#  activation_10 (Activation)  (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
#  activation_11 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.8011 - accuracy: 0.3389
# Epoch 1: val_accuracy improved from -inf to 0.44140, saving model to best_model.relu
# 1250/1250 [==============================] - 11s 5ms/step - loss: 1.8011 - accuracy: 0.3390 - val_loss: 1.5528 - val_accuracy: 0.4414
# Epoch 2/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.4843 - accuracy: 0.4638
# Epoch 2: val_accuracy improved from 0.44140 to 0.51940, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4843 - accuracy: 0.4638 - val_loss: 1.3489 - val_accuracy: 0.5194
# Epoch 3/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.3328 - accuracy: 0.5224
# Epoch 3: val_accuracy improved from 0.51940 to 0.57760, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3328 - accuracy: 0.5224 - val_loss: 1.2231 - val_accuracy: 0.5776
# Epoch 4/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.2319 - accuracy: 0.5619
# Epoch 4: val_accuracy improved from 0.57760 to 0.59710, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2325 - accuracy: 0.5617 - val_loss: 1.1526 - val_accuracy: 0.5971
# Epoch 5/25
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.1480 - accuracy: 0.5944
# Epoch 5: val_accuracy improved from 0.59710 to 0.61820, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1475 - accuracy: 0.5948 - val_loss: 1.0879 - val_accuracy: 0.6182
# Epoch 6/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.0850 - accuracy: 0.6176
# Epoch 6: val_accuracy improved from 0.61820 to 0.63670, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0856 - accuracy: 0.6172 - val_loss: 1.0276 - val_accuracy: 0.6367
# Epoch 7/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.0275 - accuracy: 0.6374
# Epoch 7: val_accuracy improved from 0.63670 to 0.64850, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0277 - accuracy: 0.6372 - val_loss: 1.0038 - val_accuracy: 0.6485
# Epoch 8/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9823 - accuracy: 0.6544
# Epoch 8: val_accuracy improved from 0.64850 to 0.67280, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9826 - accuracy: 0.6543 - val_loss: 0.9370 - val_accuracy: 0.6728
# Epoch 9/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.9404 - accuracy: 0.6722
# Epoch 9: val_accuracy improved from 0.67280 to 0.68470, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9410 - accuracy: 0.6719 - val_loss: 0.9053 - val_accuracy: 0.6847
# Epoch 10/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.9112 - accuracy: 0.6818
# Epoch 10: val_accuracy improved from 0.68470 to 0.69270, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9109 - accuracy: 0.6819 - val_loss: 0.8713 - val_accuracy: 0.6927
# Epoch 11/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8771 - accuracy: 0.6935
# Epoch 11: val_accuracy improved from 0.69270 to 0.69870, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8772 - accuracy: 0.6933 - val_loss: 0.8631 - val_accuracy: 0.6987
# Epoch 12/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8559 - accuracy: 0.7020
# Epoch 12: val_accuracy improved from 0.69870 to 0.71270, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8560 - accuracy: 0.7019 - val_loss: 0.8315 - val_accuracy: 0.7127
# Epoch 13/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8276 - accuracy: 0.7107
# Epoch 13: val_accuracy improved from 0.71270 to 0.72070, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8276 - accuracy: 0.7107 - val_loss: 0.8037 - val_accuracy: 0.7207
# Epoch 14/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.8106 - accuracy: 0.7193
# Epoch 14: val_accuracy improved from 0.72070 to 0.72810, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8106 - accuracy: 0.7191 - val_loss: 0.7802 - val_accuracy: 0.7281
# Epoch 15/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7934 - accuracy: 0.7270
# Epoch 15: val_accuracy did not improve from 0.72810
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7934 - accuracy: 0.7270 - val_loss: 0.7868 - val_accuracy: 0.7241
# Epoch 16/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7750 - accuracy: 0.7319
# Epoch 16: val_accuracy did not improve from 0.72810
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7759 - accuracy: 0.7315 - val_loss: 0.8081 - val_accuracy: 0.7225
# Epoch 17/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7605 - accuracy: 0.7397
# Epoch 17: val_accuracy improved from 0.72810 to 0.73500, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7605 - accuracy: 0.7397 - val_loss: 0.7900 - val_accuracy: 0.7350
# Epoch 18/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7445 - accuracy: 0.7428
# Epoch 18: val_accuracy did not improve from 0.73500
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7448 - accuracy: 0.7428 - val_loss: 0.7781 - val_accuracy: 0.7326
# Epoch 19/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.7335 - accuracy: 0.7483
# Epoch 19: val_accuracy improved from 0.73500 to 0.73960, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7330 - accuracy: 0.7485 - val_loss: 0.7704 - val_accuracy: 0.7396
# Epoch 20/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7233 - accuracy: 0.7504
# Epoch 20: val_accuracy improved from 0.73960 to 0.74960, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7232 - accuracy: 0.7503 - val_loss: 0.7378 - val_accuracy: 0.7496
# Epoch 21/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7154 - accuracy: 0.7555
# Epoch 21: val_accuracy improved from 0.74960 to 0.75060, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7153 - accuracy: 0.7556 - val_loss: 0.7293 - val_accuracy: 0.7506
# Epoch 22/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7037 - accuracy: 0.7610
# Epoch 22: val_accuracy did not improve from 0.75060
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7037 - accuracy: 0.7608 - val_loss: 0.7419 - val_accuracy: 0.7480
# Epoch 23/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7020 - accuracy: 0.7598
# Epoch 23: val_accuracy improved from 0.75060 to 0.76170, saving model to best_model.relu
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7026 - accuracy: 0.7595 - val_loss: 0.7145 - val_accuracy: 0.7617
# Epoch 24/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.6906 - accuracy: 0.7656
# Epoch 24: val_accuracy did not improve from 0.76170
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6912 - accuracy: 0.7655 - val_loss: 0.7167 - val_accuracy: 0.7606
# Epoch 25/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6791 - accuracy: 0.7695
# Epoch 25: val_accuracy did not improve from 0.76170
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6796 - accuracy: 0.7694 - val_loss: 0.7254 - val_accuracy: 0.7588
# Training CNN with sigmoid activation function
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_12 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_13 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_14 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_15 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 512)               2097664
#
#  activation_16 (Activation)  (None, 512)               0
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
#  activation_17 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 2.3337 - accuracy: 0.0984
# Epoch 1: val_accuracy improved from -inf to 0.10220, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 8s 5ms/step - loss: 2.3335 - accuracy: 0.0984 - val_loss: 2.3050 - val_accuracy: 0.1022
# Epoch 2/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 2.3078 - accuracy: 0.0979
# Epoch 2: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3078 - accuracy: 0.0977 - val_loss: 2.3028 - val_accuracy: 0.1022
# Epoch 3/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 2.3062 - accuracy: 0.1012
# Epoch 3: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3062 - accuracy: 0.1014 - val_loss: 2.3034 - val_accuracy: 0.0977
# Epoch 4/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 2.3047 - accuracy: 0.1033
# Epoch 4: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3047 - accuracy: 0.1034 - val_loss: 2.3042 - val_accuracy: 0.0980
# Epoch 5/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 2.3046 - accuracy: 0.1017
# Epoch 5: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3046 - accuracy: 0.1015 - val_loss: 2.3030 - val_accuracy: 0.1022
# Epoch 6/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 2.3043 - accuracy: 0.1007
# Epoch 6: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3043 - accuracy: 0.1007 - val_loss: 2.3039 - val_accuracy: 0.0952
# Epoch 7/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 2.3038 - accuracy: 0.1011
# Epoch 7: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3038 - accuracy: 0.1009 - val_loss: 2.3026 - val_accuracy: 0.0980
# Epoch 8/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 2.3036 - accuracy: 0.0992
# Epoch 8: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3036 - accuracy: 0.0992 - val_loss: 2.3030 - val_accuracy: 0.0977
# Epoch 9/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 2.3034 - accuracy: 0.0999
# Epoch 9: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3034 - accuracy: 0.0998 - val_loss: 2.3031 - val_accuracy: 0.0977
# Epoch 10/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 2.3029 - accuracy: 0.1024
# Epoch 10: val_accuracy did not improve from 0.10220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3029 - accuracy: 0.1024 - val_loss: 2.2951 - val_accuracy: 0.1022
# Epoch 11/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 2.1913 - accuracy: 0.1808
# Epoch 11: val_accuracy improved from 0.10220 to 0.26600, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.1900 - accuracy: 0.1814 - val_loss: 2.0476 - val_accuracy: 0.2660
# Epoch 12/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 2.0330 - accuracy: 0.2624
# Epoch 12: val_accuracy improved from 0.26600 to 0.30280, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.0329 - accuracy: 0.2624 - val_loss: 1.9482 - val_accuracy: 0.3028
# Epoch 13/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.9484 - accuracy: 0.2979
# Epoch 13: val_accuracy improved from 0.30280 to 0.32970, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.9481 - accuracy: 0.2980 - val_loss: 1.8825 - val_accuracy: 0.3297
# Epoch 14/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.8852 - accuracy: 0.3222
# Epoch 14: val_accuracy improved from 0.32970 to 0.33830, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.8846 - accuracy: 0.3224 - val_loss: 1.8358 - val_accuracy: 0.3383
# Epoch 15/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.8428 - accuracy: 0.3384
# Epoch 15: val_accuracy improved from 0.33830 to 0.35010, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.8428 - accuracy: 0.3384 - val_loss: 1.7983 - val_accuracy: 0.3501
# Epoch 16/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.8112 - accuracy: 0.3505
# Epoch 16: val_accuracy improved from 0.35010 to 0.36570, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.8112 - accuracy: 0.3505 - val_loss: 1.7612 - val_accuracy: 0.3657
# Epoch 17/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.7871 - accuracy: 0.3570
# Epoch 17: val_accuracy improved from 0.36570 to 0.37600, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7868 - accuracy: 0.3575 - val_loss: 1.7373 - val_accuracy: 0.3760
# Epoch 18/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.7657 - accuracy: 0.3662
# Epoch 18: val_accuracy improved from 0.37600 to 0.38670, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7656 - accuracy: 0.3663 - val_loss: 1.7148 - val_accuracy: 0.3867
# Epoch 19/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.7453 - accuracy: 0.3744
# Epoch 19: val_accuracy improved from 0.38670 to 0.38700, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7450 - accuracy: 0.3746 - val_loss: 1.7156 - val_accuracy: 0.3870
# Epoch 20/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.7222 - accuracy: 0.3808
# Epoch 20: val_accuracy improved from 0.38700 to 0.39930, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7222 - accuracy: 0.3810 - val_loss: 1.6811 - val_accuracy: 0.3993
# Epoch 21/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.7076 - accuracy: 0.3885
# Epoch 21: val_accuracy improved from 0.39930 to 0.40330, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7075 - accuracy: 0.3884 - val_loss: 1.6567 - val_accuracy: 0.4033
# Epoch 22/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.6860 - accuracy: 0.3954
# Epoch 22: val_accuracy improved from 0.40330 to 0.40760, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6856 - accuracy: 0.3958 - val_loss: 1.6404 - val_accuracy: 0.4076
# Epoch 23/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.6694 - accuracy: 0.4042
# Epoch 23: val_accuracy improved from 0.40760 to 0.42120, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6694 - accuracy: 0.4042 - val_loss: 1.6138 - val_accuracy: 0.4212
# Epoch 24/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.6505 - accuracy: 0.4085
# Epoch 24: val_accuracy improved from 0.42120 to 0.42400, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6506 - accuracy: 0.4084 - val_loss: 1.6022 - val_accuracy: 0.4240
# Epoch 25/25
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.6320 - accuracy: 0.4137
# Epoch 25: val_accuracy improved from 0.42400 to 0.42920, saving model to best_model.sigmoid
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6323 - accuracy: 0.4135 - val_loss: 1.5881 - val_accuracy: 0.4292
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7290 - accuracy: 0.7514
# Test accuracy for relu activation: 0.7513999938964844
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5608 - accuracy: 0.4428
# Test accuracy for sigmoid activation: 0.44279998540878296

# %% [markdown]
# ### **b) Based on the above experiment answer the following [5 + 2.5 + 2.5 = 10 points]**
#
# 1.   After 25 epochs, what is the best validation accuracy of the two activation functions?
# 2.   When does the validation accuracy start to improve for the sigmoid activation?
# 3. For RELU, when do you observe the saturation of validation accuracy? Saturation here refers to the accuracy change being less than 0.02 for 5 consecutive epochs or more.
#
# Provide your answers in the text box below.

# %% [markdown]
# **Answers**
#
#
# 1.  After 25 epochs, the best validation accuracy for
#
#     *   ReLU - 0.7592
#     *   Sigmoid - 0.53070
#
# 2.  Validation accuracy for the sigmoid function starts improving after the 10thn epoch.
# 3.  The saturation for validation accuracy for ReLU starts after the 16th epoch.

# %% [markdown]
# ## **6. Simple dense neural networks vs the basic CNN [25 points]**
#
# ### **a) Comparing simple dense neural networks with** *l* **hidden layers with the basic CNN [15 points]**
#
# Compare the accuracy of the **basic CNN** (with ReLu activation) defined earlier on the CIFAR10 dataset to the accuracy of simple dense neural networks (DNN) with **1** and **2** hidden layers of **512** rectified linear units each. The results of the **basic CNN** is stored in the *history_activations* dictionary. Modify the code in **base_dnn()** to obtain simple dense neural networks with **1** and **2** hidden layers of *512* rectified linear units (with a dropout rate of 0.5).
#
# Produce two graphs that contain 3 curves (one for the convolutional neural net and one for each dense neural net of 1-2 hidden layers). The *y-axis* is the accuracy and the *x-axis* is the number of epochs (\# of passes through the training set).
#
# Since neural networks take a while to train, cross-validation is not practical. Instead, produce one graph where all the curves correspond to the training accuracy and a second graph where all the curves correspond to the validation accuracy. Train the neural networks for 25 epochs. Although 25 epochs is not sufficient to reach convergence, it is sufficient to see the trend. Among the models abtained after each epoch, save the model that achieves the best validation accuracy and report its test accuracy. Save the following results in your Jupyter notebook:
#
#
# *   The two graphs for training and validation accuracy.
# *   For each architecture, print the test accuracy of the model that achieved the best validation accuracy among all epochs (i.e., one best test accuracy per network architecture).

# %%
def base_dnn(hidden_layer):
  # Define a dense neural network with 'hidden_layer' number of hidden layers.
  model = Sequential()

  '''
  TO-DO: A dense layer which takes the data as input and outputs are passed to
  the first hidden layer containing 512 units. Use 'relu' activation function
  '''
  model.add(Dense(512, activation='relu', input_shape=x_train.shape[1:]))


  '''
  TO-DO: Add a for loop for stacking the additional hidden layers based on the
  input 'hidden_layer'. Note that you have already added 1 hidden layer earlier.
  Now you need to add additional (hidden_layer-1) hidden layers so that in total
  there are 'hidden_layer' number of hidden layers. Make sure that the output
  dimension of each additional hidden layer is 512 and uses 'relu' activation.
  Add a droput of 0.5 after adding each hidden layer. You may make use of a for-
  loop to accomplish this. Note that each additional hidden layer is a dense layer.
  '''
  for i in range(hidden_layer-1):
    model.add(Dense(512, activation='relu'))

  model.add(Dropout(0.5))



  # The outputs are flattened for subsequent layers
  model.add(Flatten())

  '''
  TO-DO: Use the dense layer to generate an output of size 'num_classes'. Use
  the 'softmax' activation function.
  '''
  model.add(Dense(num_classes, activation='softmax'))


  # initiate RMSprop optimizer
  opt = keras.optimizers.RMSprop(learning_rate=0.0001, weight_decay=1e-6)

  # Compile the model before using it
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print(model.summary())

  return model

# %% [markdown]
# ### Test code to simulate this scenario (**do not modify**)
#
# **Expected runtime on Google Colab:** 60-120 minutes with TPU/GPU resources

# %%
history_dnn = dict()
for l in range(2):
  print('Training DNN with {} hidden layers'.format(l+1))
  save_best_model = ModelCheckpoint('best_model.{}hiddenlayers'.format(l+1), monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
  model =  base_dnn(l+1)
  history_dnn[l] = model.fit(x_train, y_train,
                             batch_size=batch_size,
                             epochs=epochs,
                             validation_data=(x_validate, y_validate),
                             shuffle=True,
                             callbacks=[save_best_model])

# Plot training accuracy
plt.plot(history_activations['relu'].history['accuracy'], 'x-', label='CNN + ReLu')
for l in range(2):
  plt.plot(history_dnn[l].history['accuracy'], 'o-', label='DNN with {} hidden layers'.format(l+1))

plt.title('training accuracy')
plt.ylabel('training accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Plot validation accuracy
plt.plot(history_activations['relu'].history['val_accuracy'], 'x-', label='CNN + ReLu')
for l in range(2):
  plt.plot(history_dnn[l].history['val_accuracy'], 'o-', label='DNN with {} hidden layers'.format(l+1))

plt.title('validation accuracy')
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Evaluate the best model saved (i.e., model with best validation accuracy) on the test set
for l in range(2):
  saved_model = load_model('best_model.{}hiddenlayers'.format(l+1))
  scores = saved_model.evaluate(x_test, y_test, verbose=1)
  print('Test accuracy for DNN with {} hidden layers: {}'.format(l+1, scores[1]))
# Out:
# Training DNN with 1 hidden layers
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 32, 32, 512)       2048
#
#  dropout_10 (Dropout)        (None, 32, 32, 512)       0
#
#  flatten_4 (Flatten)         (None, 524288)            0
#
#  dense_9 (Dense)             (None, 10)                5242890
#
# =================================================================
# Total params: 5244938 (20.01 MB)
# Trainable params: 5244938 (20.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.7750 - accuracy: 0.3774
# Epoch 1: val_accuracy improved from -inf to 0.42500, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.7740 - accuracy: 0.3778 - val_loss: 1.6653 - val_accuracy: 0.4250
# Epoch 2/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.5829 - accuracy: 0.4535
# Epoch 2: val_accuracy improved from 0.42500 to 0.45970, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.5825 - accuracy: 0.4536 - val_loss: 1.5807 - val_accuracy: 0.4597
# Epoch 3/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.5202 - accuracy: 0.4707
# Epoch 3: val_accuracy improved from 0.45970 to 0.46900, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.5204 - accuracy: 0.4701 - val_loss: 1.5347 - val_accuracy: 0.4690
# Epoch 4/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.4826 - accuracy: 0.4890
# Epoch 4: val_accuracy did not improve from 0.46900
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4831 - accuracy: 0.4888 - val_loss: 1.5391 - val_accuracy: 0.4666
# Epoch 5/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.4557 - accuracy: 0.4978
# Epoch 5: val_accuracy improved from 0.46900 to 0.47770, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4559 - accuracy: 0.4975 - val_loss: 1.5332 - val_accuracy: 0.4777
# Epoch 6/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.4347 - accuracy: 0.5057
# Epoch 6: val_accuracy did not improve from 0.47770
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.4346 - accuracy: 0.5057 - val_loss: 1.5099 - val_accuracy: 0.4759
# Epoch 7/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.4175 - accuracy: 0.5109
# Epoch 7: val_accuracy improved from 0.47770 to 0.48490, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4178 - accuracy: 0.5107 - val_loss: 1.4911 - val_accuracy: 0.4849
# Epoch 8/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.4031 - accuracy: 0.5148
# Epoch 8: val_accuracy improved from 0.48490 to 0.48680, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4029 - accuracy: 0.5151 - val_loss: 1.4927 - val_accuracy: 0.4868
# Epoch 9/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.3888 - accuracy: 0.5204
# Epoch 9: val_accuracy did not improve from 0.48680
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3893 - accuracy: 0.5203 - val_loss: 1.4912 - val_accuracy: 0.4824
# Epoch 10/25
# 1234/1250 [============================>.] - ETA: 0s - loss: 1.3757 - accuracy: 0.5262
# Epoch 10: val_accuracy improved from 0.48680 to 0.49110, saving model to best_model.1hiddenlayers
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3765 - accuracy: 0.5260 - val_loss: 1.4823 - val_accuracy: 0.4911
# Epoch 11/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.3656 - accuracy: 0.5294
# Epoch 11: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.3650 - accuracy: 0.5296 - val_loss: 1.4856 - val_accuracy: 0.4900
# Epoch 12/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.3535 - accuracy: 0.5331
# Epoch 12: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.3536 - accuracy: 0.5331 - val_loss: 1.4908 - val_accuracy: 0.4841
# Epoch 13/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.3446 - accuracy: 0.5403
# Epoch 13: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.3447 - accuracy: 0.5402 - val_loss: 1.4976 - val_accuracy: 0.4858
# Epoch 14/25
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.3357 - accuracy: 0.5425
# Epoch 14: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.3361 - accuracy: 0.5424 - val_loss: 1.4821 - val_accuracy: 0.4909
# Epoch 15/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.3261 - accuracy: 0.5438
# Epoch 15: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.3261 - accuracy: 0.5438 - val_loss: 1.5024 - val_accuracy: 0.4808
# Epoch 16/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.3169 - accuracy: 0.5465
# Epoch 16: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3169 - accuracy: 0.5466 - val_loss: 1.4954 - val_accuracy: 0.4827
# Epoch 17/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.3079 - accuracy: 0.5533
# Epoch 17: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3080 - accuracy: 0.5533 - val_loss: 1.4785 - val_accuracy: 0.4907
# Epoch 18/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.3000 - accuracy: 0.5543
# Epoch 18: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2992 - accuracy: 0.5547 - val_loss: 1.4813 - val_accuracy: 0.4906
# Epoch 19/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.2921 - accuracy: 0.5586
# Epoch 19: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2924 - accuracy: 0.5585 - val_loss: 1.4916 - val_accuracy: 0.4874
# Epoch 20/25
# 1235/1250 [============================>.] - ETA: 0s - loss: 1.2849 - accuracy: 0.5618
# Epoch 20: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2845 - accuracy: 0.5616 - val_loss: 1.4939 - val_accuracy: 0.4879
# Epoch 21/25
# 1234/1250 [============================>.] - ETA: 0s - loss: 1.2784 - accuracy: 0.5613
# Epoch 21: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2783 - accuracy: 0.5615 - val_loss: 1.4995 - val_accuracy: 0.4871
# Epoch 22/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2698 - accuracy: 0.5678
# Epoch 22: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2701 - accuracy: 0.5676 - val_loss: 1.4951 - val_accuracy: 0.4898
# Epoch 23/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.2637 - accuracy: 0.5692
# Epoch 23: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2634 - accuracy: 0.5693 - val_loss: 1.4975 - val_accuracy: 0.4889
# Epoch 24/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.2550 - accuracy: 0.5729
# Epoch 24: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2560 - accuracy: 0.5727 - val_loss: 1.4928 - val_accuracy: 0.4866
# Epoch 25/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2516 - accuracy: 0.5748
# Epoch 25: val_accuracy did not improve from 0.49110
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.2518 - accuracy: 0.5747 - val_loss: 1.5144 - val_accuracy: 0.4850
# Training DNN with 2 hidden layers
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 32, 32, 512)       2048
#
#  dense_11 (Dense)            (None, 32, 32, 512)       262656
#
#  dropout_11 (Dropout)        (None, 32, 32, 512)       0
#
#  flatten_5 (Flatten)         (None, 524288)            0
#
#  dense_12 (Dense)            (None, 10)                5242890
#
# =================================================================
# Total params: 5507594 (21.01 MB)
# Trainable params: 5507594 (21.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.7168 - accuracy: 0.3953
# Epoch 1: val_accuracy improved from -inf to 0.43130, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.7148 - accuracy: 0.3961 - val_loss: 1.6231 - val_accuracy: 0.4313
# Epoch 2/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.5273 - accuracy: 0.4685
# Epoch 2: val_accuracy improved from 0.43130 to 0.47490, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.5274 - accuracy: 0.4685 - val_loss: 1.5190 - val_accuracy: 0.4749
# Epoch 3/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.4603 - accuracy: 0.4924
# Epoch 3: val_accuracy improved from 0.47490 to 0.48660, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.4600 - accuracy: 0.4924 - val_loss: 1.4988 - val_accuracy: 0.4866
# Epoch 4/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.4189 - accuracy: 0.5071
# Epoch 4: val_accuracy did not improve from 0.48660
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4187 - accuracy: 0.5072 - val_loss: 1.4945 - val_accuracy: 0.4855
# Epoch 5/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.3868 - accuracy: 0.5201
# Epoch 5: val_accuracy improved from 0.48660 to 0.49420, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.3875 - accuracy: 0.5198 - val_loss: 1.4800 - val_accuracy: 0.4942
# Epoch 6/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.3600 - accuracy: 0.5270
# Epoch 6: val_accuracy did not improve from 0.49420
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3599 - accuracy: 0.5271 - val_loss: 1.4641 - val_accuracy: 0.4929
# Epoch 7/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.3365 - accuracy: 0.5398
# Epoch 7: val_accuracy improved from 0.49420 to 0.49500, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.3358 - accuracy: 0.5400 - val_loss: 1.4505 - val_accuracy: 0.4950
# Epoch 8/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.3147 - accuracy: 0.5481
# Epoch 8: val_accuracy improved from 0.49500 to 0.50120, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.3150 - accuracy: 0.5478 - val_loss: 1.4501 - val_accuracy: 0.5012
# Epoch 9/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.2932 - accuracy: 0.5545
# Epoch 9: val_accuracy did not improve from 0.50120
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2935 - accuracy: 0.5544 - val_loss: 1.4469 - val_accuracy: 0.5011
# Epoch 10/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.2745 - accuracy: 0.5637
# Epoch 10: val_accuracy did not improve from 0.50120
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2749 - accuracy: 0.5635 - val_loss: 1.4628 - val_accuracy: 0.4951
# Epoch 11/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.2585 - accuracy: 0.5689
# Epoch 11: val_accuracy did not improve from 0.50120
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2585 - accuracy: 0.5688 - val_loss: 1.4522 - val_accuracy: 0.5003
# Epoch 12/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.2406 - accuracy: 0.5749
# Epoch 12: val_accuracy improved from 0.50120 to 0.50150, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.2400 - accuracy: 0.5751 - val_loss: 1.4597 - val_accuracy: 0.5015
# Epoch 13/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.2231 - accuracy: 0.5814
# Epoch 13: val_accuracy improved from 0.50150 to 0.50630, saving model to best_model.2hiddenlayers
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.2227 - accuracy: 0.5816 - val_loss: 1.4625 - val_accuracy: 0.5063
# Epoch 14/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.2056 - accuracy: 0.5899
# Epoch 14: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2057 - accuracy: 0.5900 - val_loss: 1.4725 - val_accuracy: 0.4987
# Epoch 15/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1880 - accuracy: 0.5953
# Epoch 15: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1879 - accuracy: 0.5954 - val_loss: 1.4771 - val_accuracy: 0.5018
# Epoch 16/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.1741 - accuracy: 0.6023
# Epoch 16: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1738 - accuracy: 0.6025 - val_loss: 1.4704 - val_accuracy: 0.5026
# Epoch 17/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1547 - accuracy: 0.6087
# Epoch 17: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1546 - accuracy: 0.6087 - val_loss: 1.4953 - val_accuracy: 0.4975
# Epoch 18/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1385 - accuracy: 0.6135
# Epoch 18: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1389 - accuracy: 0.6134 - val_loss: 1.4972 - val_accuracy: 0.4974
# Epoch 19/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1230 - accuracy: 0.6213
# Epoch 19: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1228 - accuracy: 0.6214 - val_loss: 1.5251 - val_accuracy: 0.4900
# Epoch 20/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1047 - accuracy: 0.6271
# Epoch 20: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1050 - accuracy: 0.6270 - val_loss: 1.5197 - val_accuracy: 0.4919
# Epoch 21/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.0898 - accuracy: 0.6336
# Epoch 21: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0899 - accuracy: 0.6335 - val_loss: 1.5250 - val_accuracy: 0.4907
# Epoch 22/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0765 - accuracy: 0.6371
# Epoch 22: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0765 - accuracy: 0.6371 - val_loss: 1.5517 - val_accuracy: 0.4927
# Epoch 23/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.0589 - accuracy: 0.6438
# Epoch 23: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0590 - accuracy: 0.6438 - val_loss: 1.5362 - val_accuracy: 0.4898
# Epoch 24/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.0424 - accuracy: 0.6494
# Epoch 24: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0425 - accuracy: 0.6493 - val_loss: 1.5474 - val_accuracy: 0.4902
# Epoch 25/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.0260 - accuracy: 0.6579
# Epoch 25: val_accuracy did not improve from 0.50630
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0261 - accuracy: 0.6578 - val_loss: 1.5896 - val_accuracy: 0.4740
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4557 - accuracy: 0.4915
# Test accuracy for DNN with 1 hidden layers: 0.49149999022483826
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4349 - accuracy: 0.5009
# Test accuracy for DNN with 2 hidden layers: 0.5008999705314636

# %% [markdown]
# ### **b) Based on the above experiment answer the following [2.5X4 = 10 points]**
#
#
# 1. What are the best validation accuracy of the comparison models after 25 epochs?
#
# 2. Do you get any added benefit by adding more hidden layers?
#
# 3. Is the validation accuracy a strictly non-decreasing function of the number of epochs?
#
# 4. Would you prefer a CNN or a DNN if you were to classify images based on your experimental results? Why?
#
# Provide your answers in the text box below.

# %% [markdown]
# ### **Answers**
#
#
# 1. CNN with ReLU still is at the top with a validation accuracy of  0.75920 followed by 0.50630 for DNN with 2 hidden layers and 0.49110 for DNN with a single hidden layer.
#
# 2. For this particular exercise(images), there's no added benefit from adding more hidden layers. My hunch is that adding hidden layers just adds unnecessary features in the DNN which don't go well with spatial data(pixels).
#
# 3. No. In all cases, validation accuracy is not a strictly non-decreasing function of the number of epochs as can be seen in the dips in the graphs.
#
# 4. CNN is a clear winner for me. For image classification tasks, CNN are optimal since they're great at expressing spatially local data more efficiently with less parameters compared to a DNN. This is also clear from the graphs that CNN outperforms DNN by getting a validation accuracy of 0.75920 compared to DNNs which struggle get over 0.50.

# %% [markdown]
# ## **7. The effects of dropout on CNN [25 points]**
#
# ### **a) Compare the accuracy achieved with and without drop on the basic CNN [15 points]**
#
# Complete the code in `base_cnn_drop()` to turn the dropout layer on/off dropout based on the input `dropout`.
#
# Produce two graphs (one for training accuracy and the other one for validation accuracy) that each contain 2 curves (dropout and no dropout). The y-axis is the accuracy and the x-axis is the number of epochs. Produce curves for up to 25 epochs.
#
# *   The two graphs for training and validation accuracy.
# *   For both dropout and no dropout, print the test accuracy of the model that achieved the best validation accuracy among all epochs.

# %%
def base_cnn_drop(dropout):
  """
  TO-DO: Copy the code from the base_cnn() function above and paste it here. This
  code has three occurences of the dropout layer. Modify those occurences so that
  dropout layer is added based on the input 'dropout'. See the simulation code
  below to see the possible values of input 'dropout'.
  """

  model = Sequential()
  dropout_prob = 0.0
  if dropout:
    dropout_prob = 0.25

  model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
  model.add(Activation('relu'))
  model.add(Conv2D(32, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(dropout_prob))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(dropout_prob))
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
  model.add(Dropout(dropout_prob))
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
  opt = keras.optimizers.RMSprop(learning_rate=0.0001, weight_decay=1e-6)
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print(model.summary())

  return model

  return model

# %% [markdown]
# ### Test code to simulate this scenario (**do not modify**)
#
# **Expected runtime on Google Colab:** 30-60 minutes with TPU/GPU resources

# %%
history_dd = dict()

for dropout in [True, False]:
  model = base_cnn_drop(dropout)
  model_name = ('no dropout', 'dropout')[dropout]
  save_best_model = ModelCheckpoint('best_model.{}'.format(model_name),
                                    monitor='val_accuracy', mode='max',
                                    save_best_only=True, verbose=1)

  history = model.fit(x_train, y_train,
                      batch_size=batch_size,
                      epochs=epochs,
                      validation_data=(x_validate, y_validate),
                      shuffle=True,
                      callbacks=[save_best_model])

  history_dd[model_name] = history


# Plot training accuracy
for model_name, history in history_dd.items():
  plt.plot(history.history['accuracy'], 'o-', label='CNN with {}'.format(model_name))
plt.plot(history.history['accuracy'])
plt.title('training accuracy')
plt.ylabel('training accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Plot validation accuracy
for model_name, history in history_dd.items():
  plt.plot(history.history['val_accuracy'], 'o-', label='CNN with {}'.format(model_name))
plt.title('validation accuracy')
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Evaluate the best model saved (i.e., model with best validation accuracy) on the test set
for model_name in history_dd.keys():
  saved_model = load_model('best_model.{}'.format(model_name))
  scores = saved_model.evaluate(x_test, y_test, verbose=1)
  print('Test accuracy for CNN with {} :'.format(model_name, scores[1]))
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_46 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_70 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_71 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_24 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_39 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_72 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_73 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_25 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_40 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_15 (Flatten)        (None, 4096)              0
#
#  dense_31 (Dense)            (None, 512)               2097664
#
#  activation_74 (Activation)  (None, 512)               0
#
#  dropout_41 (Dropout)        (None, 512)               0
#
#  dense_32 (Dense)            (None, 10)                5130
#
#  activation_75 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.8277 - accuracy: 0.3393
# Epoch 1: val_accuracy improved from -inf to 0.43980, saving model to best_model.dropout
# 1250/1250 [==============================] - 9s 5ms/step - loss: 1.8275 - accuracy: 0.3395 - val_loss: 1.5768 - val_accuracy: 0.4398
# Epoch 2/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.4903 - accuracy: 0.4652
# Epoch 2: val_accuracy improved from 0.43980 to 0.52060, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.4904 - accuracy: 0.4652 - val_loss: 1.3733 - val_accuracy: 0.5206
# Epoch 3/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.3273 - accuracy: 0.5267
# Epoch 3: val_accuracy improved from 0.52060 to 0.56400, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.3272 - accuracy: 0.5267 - val_loss: 1.2493 - val_accuracy: 0.5640
# Epoch 4/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.2098 - accuracy: 0.5716
# Epoch 4: val_accuracy improved from 0.56400 to 0.61080, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.2100 - accuracy: 0.5716 - val_loss: 1.1255 - val_accuracy: 0.6108
# Epoch 5/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1150 - accuracy: 0.6082
# Epoch 5: val_accuracy improved from 0.61080 to 0.61820, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.1152 - accuracy: 0.6082 - val_loss: 1.1043 - val_accuracy: 0.6182
# Epoch 6/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0408 - accuracy: 0.6333
# Epoch 6: val_accuracy improved from 0.61820 to 0.64140, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.0410 - accuracy: 0.6334 - val_loss: 1.0269 - val_accuracy: 0.6414
# Epoch 7/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.9786 - accuracy: 0.6586
# Epoch 7: val_accuracy improved from 0.64140 to 0.66970, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9785 - accuracy: 0.6586 - val_loss: 0.9504 - val_accuracy: 0.6697
# Epoch 8/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9243 - accuracy: 0.6780
# Epoch 8: val_accuracy improved from 0.66970 to 0.68410, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9241 - accuracy: 0.6781 - val_loss: 0.9181 - val_accuracy: 0.6841
# Epoch 9/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.8785 - accuracy: 0.6920
# Epoch 9: val_accuracy improved from 0.68410 to 0.69440, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8780 - accuracy: 0.6923 - val_loss: 0.8835 - val_accuracy: 0.6944
# Epoch 10/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.8420 - accuracy: 0.7074
# Epoch 10: val_accuracy improved from 0.69440 to 0.70310, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8421 - accuracy: 0.7074 - val_loss: 0.8643 - val_accuracy: 0.7031
# Epoch 11/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.8045 - accuracy: 0.7208
# Epoch 11: val_accuracy improved from 0.70310 to 0.71640, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8048 - accuracy: 0.7205 - val_loss: 0.8272 - val_accuracy: 0.7164
# Epoch 12/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7706 - accuracy: 0.7314
# Epoch 12: val_accuracy improved from 0.71640 to 0.72880, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7704 - accuracy: 0.7315 - val_loss: 0.7914 - val_accuracy: 0.7288
# Epoch 13/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.7416 - accuracy: 0.7416
# Epoch 13: val_accuracy improved from 0.72880 to 0.72950, saving model to best_model.dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7410 - accuracy: 0.7416 - val_loss: 0.7855 - val_accuracy: 0.7295
# Epoch 14/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.7553
# Epoch 14: val_accuracy did not improve from 0.72950
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7076 - accuracy: 0.7554 - val_loss: 0.8546 - val_accuracy: 0.7112
# Epoch 15/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6826 - accuracy: 0.7631
# Epoch 15: val_accuracy improved from 0.72950 to 0.73860, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6826 - accuracy: 0.7630 - val_loss: 0.7642 - val_accuracy: 0.7386
# Epoch 16/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.6608 - accuracy: 0.7692
# Epoch 16: val_accuracy improved from 0.73860 to 0.75370, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6605 - accuracy: 0.7695 - val_loss: 0.7228 - val_accuracy: 0.7537
# Epoch 17/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6338 - accuracy: 0.7812
# Epoch 17: val_accuracy did not improve from 0.75370
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6336 - accuracy: 0.7811 - val_loss: 0.7350 - val_accuracy: 0.7510
# Epoch 18/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6123 - accuracy: 0.7895
# Epoch 18: val_accuracy improved from 0.75370 to 0.76030, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6124 - accuracy: 0.7895 - val_loss: 0.7035 - val_accuracy: 0.7603
# Epoch 19/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.5923 - accuracy: 0.7962
# Epoch 19: val_accuracy did not improve from 0.76030
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5925 - accuracy: 0.7962 - val_loss: 0.7277 - val_accuracy: 0.7550
# Epoch 20/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.5749 - accuracy: 0.8017
# Epoch 20: val_accuracy improved from 0.76030 to 0.76640, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.5750 - accuracy: 0.8020 - val_loss: 0.7004 - val_accuracy: 0.7664
# Epoch 21/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.5554 - accuracy: 0.8098
# Epoch 21: val_accuracy did not improve from 0.76640
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.5552 - accuracy: 0.8098 - val_loss: 0.7063 - val_accuracy: 0.7646
# Epoch 22/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.5433 - accuracy: 0.8144
# Epoch 22: val_accuracy improved from 0.76640 to 0.76750, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.5433 - accuracy: 0.8142 - val_loss: 0.6897 - val_accuracy: 0.7675
# Epoch 23/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.5292 - accuracy: 0.8189
# Epoch 23: val_accuracy did not improve from 0.76750
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.5289 - accuracy: 0.8189 - val_loss: 0.7008 - val_accuracy: 0.7668
# Epoch 24/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.5095 - accuracy: 0.8273
# Epoch 24: val_accuracy improved from 0.76750 to 0.77280, saving model to best_model.dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.5095 - accuracy: 0.8273 - val_loss: 0.6925 - val_accuracy: 0.7728
# Epoch 25/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.5001 - accuracy: 0.8281
# Epoch 25: val_accuracy did not improve from 0.77280
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.4999 - accuracy: 0.8282 - val_loss: 0.7069 - val_accuracy: 0.7718
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_50 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_76 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_51 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_77 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_26 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_42 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_52 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_78 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_53 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_79 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_27 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_43 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_16 (Flatten)        (None, 4096)              0
#
#  dense_33 (Dense)            (None, 512)               2097664
#
#  activation_80 (Activation)  (None, 512)               0
#
#  dropout_44 (Dropout)        (None, 512)               0
#
#  dense_34 (Dense)            (None, 10)                5130
#
#  activation_81 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.7047 - accuracy: 0.3911
# Epoch 1: val_accuracy improved from -inf to 0.48270, saving model to best_model.no dropout
# 1250/1250 [==============================] - 8s 5ms/step - loss: 1.7027 - accuracy: 0.3917 - val_loss: 1.4528 - val_accuracy: 0.4827
# Epoch 2/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.3698 - accuracy: 0.5135
# Epoch 2: val_accuracy improved from 0.48270 to 0.53880, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3691 - accuracy: 0.5137 - val_loss: 1.2825 - val_accuracy: 0.5388
# Epoch 3/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.2124 - accuracy: 0.5702
# Epoch 3: val_accuracy improved from 0.53880 to 0.57820, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2126 - accuracy: 0.5702 - val_loss: 1.1811 - val_accuracy: 0.5782
# Epoch 4/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.0961 - accuracy: 0.6156
# Epoch 4: val_accuracy improved from 0.57820 to 0.61580, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0966 - accuracy: 0.6156 - val_loss: 1.1006 - val_accuracy: 0.6158
# Epoch 5/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0011 - accuracy: 0.6527
# Epoch 5: val_accuracy improved from 0.61580 to 0.64630, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0007 - accuracy: 0.6528 - val_loss: 1.0181 - val_accuracy: 0.6463
# Epoch 6/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.9156 - accuracy: 0.6822
# Epoch 6: val_accuracy improved from 0.64630 to 0.66450, saving model to best_model.no dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9160 - accuracy: 0.6821 - val_loss: 0.9742 - val_accuracy: 0.6645
# Epoch 7/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8436 - accuracy: 0.7089
# Epoch 7: val_accuracy improved from 0.66450 to 0.68500, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8436 - accuracy: 0.7089 - val_loss: 0.9150 - val_accuracy: 0.6850
# Epoch 8/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7787 - accuracy: 0.7315
# Epoch 8: val_accuracy improved from 0.68500 to 0.68520, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7789 - accuracy: 0.7315 - val_loss: 0.9185 - val_accuracy: 0.6852
# Epoch 9/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7204 - accuracy: 0.7524
# Epoch 9: val_accuracy improved from 0.68520 to 0.69870, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7203 - accuracy: 0.7525 - val_loss: 0.8781 - val_accuracy: 0.6987
# Epoch 10/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6621 - accuracy: 0.7725
# Epoch 10: val_accuracy improved from 0.69870 to 0.70540, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6621 - accuracy: 0.7725 - val_loss: 0.8726 - val_accuracy: 0.7054
# Epoch 11/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.6051 - accuracy: 0.7932
# Epoch 11: val_accuracy improved from 0.70540 to 0.71450, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6043 - accuracy: 0.7933 - val_loss: 0.8420 - val_accuracy: 0.7145
# Epoch 12/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.8137
# Epoch 12: val_accuracy improved from 0.71450 to 0.71580, saving model to best_model.no dropout
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.5470 - accuracy: 0.8138 - val_loss: 0.8390 - val_accuracy: 0.7158
# Epoch 13/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.4907 - accuracy: 0.8324
# Epoch 13: val_accuracy improved from 0.71580 to 0.73060, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4907 - accuracy: 0.8324 - val_loss: 0.8388 - val_accuracy: 0.7306
# Epoch 14/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.4361 - accuracy: 0.8524
# Epoch 14: val_accuracy did not improve from 0.73060
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4359 - accuracy: 0.8522 - val_loss: 0.8641 - val_accuracy: 0.7286
# Epoch 15/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.3795 - accuracy: 0.8723
# Epoch 15: val_accuracy did not improve from 0.73060
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.3803 - accuracy: 0.8719 - val_loss: 0.8573 - val_accuracy: 0.7306
# Epoch 16/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.3258 - accuracy: 0.8916
# Epoch 16: val_accuracy improved from 0.73060 to 0.74200, saving model to best_model.no dropout
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3263 - accuracy: 0.8914 - val_loss: 0.8477 - val_accuracy: 0.7420
# Epoch 17/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.9074
# Epoch 17: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.2792 - accuracy: 0.9074 - val_loss: 0.9453 - val_accuracy: 0.7322
# Epoch 18/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2293 - accuracy: 0.9258
# Epoch 18: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.2294 - accuracy: 0.9258 - val_loss: 0.9860 - val_accuracy: 0.7263
# Epoch 19/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.1910 - accuracy: 0.9396
# Epoch 19: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.1910 - accuracy: 0.9396 - val_loss: 1.0521 - val_accuracy: 0.7305
# Epoch 20/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.9508
# Epoch 20: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.1526 - accuracy: 0.9507 - val_loss: 1.1136 - val_accuracy: 0.7295
# Epoch 21/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9631
# Epoch 21: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.1215 - accuracy: 0.9629 - val_loss: 1.1690 - val_accuracy: 0.7301
# Epoch 22/25
# 1236/1250 [============================>.] - ETA: 0s - loss: 0.0963 - accuracy: 0.9698
# Epoch 22: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.0966 - accuracy: 0.9697 - val_loss: 1.2409 - val_accuracy: 0.7332
# Epoch 23/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9774
# Epoch 23: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.0766 - accuracy: 0.9774 - val_loss: 1.3121 - val_accuracy: 0.7356
# Epoch 24/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9816
# Epoch 24: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.0597 - accuracy: 0.9816 - val_loss: 1.3962 - val_accuracy: 0.7331
# Epoch 25/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9855
# Epoch 25: val_accuracy did not improve from 0.74200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.0495 - accuracy: 0.9854 - val_loss: 1.4768 - val_accuracy: 0.7301
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7040 - accuracy: 0.7663
# Test accuracy for CNN with dropout :
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8572 - accuracy: 0.7414
# Test accuracy for CNN with no dropout :

# %% [markdown]
# ### **b) Based on the above experiment answer the following [2.5x4 = 10 points]**
#
# 1. What is the training accuracy of both the models after 25 epochs?
#
# 2. What is the best validation accuracy of both the models after 25 epochs?
#
# 3. Between the two models (CNN with dropout and CNN without dropout), which one fits the training data better? Does this model fit the validation data better as well?
#
# 4. Based on your previous answer, which model would you prefer when deploying your ML model for image classification?
#
#
# Provide your answers in the text box below.

# %% [markdown]
# ### **Answers**
#
#
# 1. For model with "no dropout" - 0.9855
#
#    For model with "dropout" - 0.8281
#
# 2. For model with "no dropout" - 0.7414
#
#    For model with "dropout" - 0.7663
#
# 3. CNN without dropout fits the training data better but it does not fit the validation data as well as the the model with dropout. This can be attributed to overfitting.
#
# 4. I would prefer the model with dropout.

# %% [markdown]
# ## **8. The effects of optimizers on the CNN [15 points]**
#
# ### **a) Compare the accuracy achieved when training the basic CNN with RMSprop, Adagrad and Adam [10 points]**.
# Modify the code in `base_cnn_opt()` to use the **Adagrad** and **Adam** optimizers (with default parameters) besides the **RMSprop**. Produce two graphs (one for training accuracy and the other one for validation accuracy) that each contain 3 curves (for **RMSprop**, **Adagrad** and **Adam**). The y-axis is the accuracy and the x-axis is the number of epochs. Produce curves for as many epochs as you can up to 100 epochs.
#
# *   The two graphs for training and validation accuracy.
# *   For each optimizer print the test accuracy of the model that achieved the best validation accuracy among all epochs (i.e., one best test accuracy per optimizer).

# %%
def base_cnn_opt(optimizer):
  """
  TO-DO: Copy the code from the base_cnn() function above and paste it here.
  This started code uses the RMSprop for learning the weights of the basic CNN.
  Modify the code so that it can work with Adagrad and Adam optimizers (besides
  the provided RMSprop optimizer). Don't change the hyperparameters of the
  RMSprop optimizer. For Adam and Adagrad, use the default hyperparameters. Refer
  to the simulation code below to understand the possible values that the input
  'optimizer' may take and accordingly write your code.
  """
  model = Sequential()
  model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
  model.add(Activation('relu'))
  model.add(Conv2D(32, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
  if optimizer == 'RMSprop':
    opt = keras.optimizers.RMSprop(learning_rate=0.0001, weight_decay=1e-6)
  elif optimizer == 'Adam':
    opt = keras.optimizers.Adam()
  else:
    opt = keras.optimizers.Adagrad()
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print(model.summary())

  return model

# %% [markdown]
# ### Test code to simulate the scenario (**do not modify**)
#
# **Expected runtime on Google Colab:** 60-90 minutes with TPU/GPU resources

# %%
history_opt = dict()

for optimizer in ['RMSprop', 'Adam', 'Adagrad']:
  save_best_model = ModelCheckpoint('best_model.{}'.format(optimizer), monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
  model = base_cnn_opt(optimizer)
  history_opt[optimizer] = model.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_data=(x_validate, y_validate),
                          shuffle=True,
                          callbacks=[save_best_model])

# Plot training accuracy
for model_name, history in history_opt.items():
  plt.plot(history.history['accuracy'], 'o-', label='CNN + {} optimizer'.format(model_name))
plt.plot(history.history['accuracy'])
plt.title('training accuracy')
plt.ylabel('training accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Plot validation accuracy
for model_name, history in history_opt.items():
  plt.plot(history.history['val_accuracy'], 'o-', label='CNN + {} optimizer'.format(model_name))
plt.title('validation accuracy')
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Evaluate the best model saved (i.e., model with best validation accuracy) on the test set
for optimizer in ['RMSprop', 'Adam', 'Adagrad']:
  saved_model = load_model('best_model.{}'.format(optimizer))
  scores = saved_model.evaluate(x_test, y_test, verbose=1)
  print('Test accuracy for CNN + {} optimizer: {}'.format(optimizer, scores[1]))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_42 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_43 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_14 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_24 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_44 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_45 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_15 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_25 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_10 (Flatten)        (None, 4096)              0
#
#  dense_21 (Dense)            (None, 512)               2097664
#
#  activation_46 (Activation)  (None, 512)               0
#
#  dropout_26 (Dropout)        (None, 512)               0
#
#  dense_22 (Dense)            (None, 10)                5130
#
#  activation_47 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.8561 - accuracy: 0.3228
# Epoch 1: val_accuracy improved from -inf to 0.43410, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 9s 5ms/step - loss: 1.8556 - accuracy: 0.3230 - val_loss: 1.5863 - val_accuracy: 0.4341
# Epoch 2/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.5310 - accuracy: 0.4472
# Epoch 2: val_accuracy improved from 0.43410 to 0.49420, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.5309 - accuracy: 0.4472 - val_loss: 1.4137 - val_accuracy: 0.4942
# Epoch 3/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.3693 - accuracy: 0.5085
# Epoch 3: val_accuracy improved from 0.49420 to 0.56030, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3692 - accuracy: 0.5085 - val_loss: 1.2493 - val_accuracy: 0.5603
# Epoch 4/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.2552 - accuracy: 0.5541
# Epoch 4: val_accuracy improved from 0.56030 to 0.58810, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2543 - accuracy: 0.5545 - val_loss: 1.1624 - val_accuracy: 0.5881
# Epoch 5/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1674 - accuracy: 0.5861
# Epoch 5: val_accuracy improved from 0.58810 to 0.62370, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.1669 - accuracy: 0.5862 - val_loss: 1.0829 - val_accuracy: 0.6237
# Epoch 6/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0948 - accuracy: 0.6126
# Epoch 6: val_accuracy improved from 0.62370 to 0.62660, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.0948 - accuracy: 0.6126 - val_loss: 1.0686 - val_accuracy: 0.6266
# Epoch 7/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.0390 - accuracy: 0.6331
# Epoch 7: val_accuracy improved from 0.62660 to 0.65990, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0383 - accuracy: 0.6333 - val_loss: 0.9654 - val_accuracy: 0.6599
# Epoch 8/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.9928 - accuracy: 0.6483
# Epoch 8: val_accuracy did not improve from 0.65990
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.9921 - accuracy: 0.6485 - val_loss: 0.9650 - val_accuracy: 0.6552
# Epoch 9/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9538 - accuracy: 0.6651
# Epoch 9: val_accuracy improved from 0.65990 to 0.67910, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9540 - accuracy: 0.6649 - val_loss: 0.9176 - val_accuracy: 0.6791
# Epoch 10/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.9160 - accuracy: 0.6786
# Epoch 10: val_accuracy improved from 0.67910 to 0.69630, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9168 - accuracy: 0.6781 - val_loss: 0.8734 - val_accuracy: 0.6963
# Epoch 11/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8849 - accuracy: 0.6921
# Epoch 11: val_accuracy improved from 0.69630 to 0.70720, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8846 - accuracy: 0.6921 - val_loss: 0.8455 - val_accuracy: 0.7072
# Epoch 12/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8528 - accuracy: 0.7017
# Epoch 12: val_accuracy did not improve from 0.70720
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8527 - accuracy: 0.7017 - val_loss: 0.8330 - val_accuracy: 0.7055
# Epoch 13/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8284 - accuracy: 0.7098
# Epoch 13: val_accuracy improved from 0.70720 to 0.72060, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8289 - accuracy: 0.7099 - val_loss: 0.8065 - val_accuracy: 0.7206
# Epoch 14/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 0.8050 - accuracy: 0.7200
# Epoch 14: val_accuracy improved from 0.72060 to 0.72200, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8059 - accuracy: 0.7197 - val_loss: 0.8084 - val_accuracy: 0.7220
# Epoch 15/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.7831 - accuracy: 0.7296
# Epoch 15: val_accuracy did not improve from 0.72200
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7824 - accuracy: 0.7298 - val_loss: 0.8254 - val_accuracy: 0.7169
# Epoch 16/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7725 - accuracy: 0.7335
# Epoch 16: val_accuracy improved from 0.72200 to 0.73160, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7726 - accuracy: 0.7335 - val_loss: 0.7802 - val_accuracy: 0.7316
# Epoch 17/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.7503 - accuracy: 0.7383
# Epoch 17: val_accuracy improved from 0.73160 to 0.73830, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7505 - accuracy: 0.7383 - val_loss: 0.7602 - val_accuracy: 0.7383
# Epoch 18/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 0.7369 - accuracy: 0.7465
# Epoch 18: val_accuracy did not improve from 0.73830
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7362 - accuracy: 0.7467 - val_loss: 0.7847 - val_accuracy: 0.7319
# Epoch 19/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.7235 - accuracy: 0.7495
# Epoch 19: val_accuracy improved from 0.73830 to 0.74140, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7238 - accuracy: 0.7494 - val_loss: 0.7815 - val_accuracy: 0.7414
# Epoch 20/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7101 - accuracy: 0.7561
# Epoch 20: val_accuracy improved from 0.74140 to 0.74190, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7100 - accuracy: 0.7561 - val_loss: 0.7440 - val_accuracy: 0.7419
# Epoch 21/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6964 - accuracy: 0.7603
# Epoch 21: val_accuracy improved from 0.74190 to 0.75010, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6967 - accuracy: 0.7601 - val_loss: 0.7333 - val_accuracy: 0.7501
# Epoch 22/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6890 - accuracy: 0.7640
# Epoch 22: val_accuracy did not improve from 0.75010
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.6887 - accuracy: 0.7639 - val_loss: 0.7390 - val_accuracy: 0.7493
# Epoch 23/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.7665
# Epoch 23: val_accuracy improved from 0.75010 to 0.75240, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6813 - accuracy: 0.7667 - val_loss: 0.7238 - val_accuracy: 0.7524
# Epoch 24/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6678 - accuracy: 0.7718
# Epoch 24: val_accuracy improved from 0.75240 to 0.75500, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6681 - accuracy: 0.7715 - val_loss: 0.7193 - val_accuracy: 0.7550
# Epoch 25/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6562 - accuracy: 0.7761
# Epoch 25: val_accuracy improved from 0.75500 to 0.76150, saving model to best_model.RMSprop
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6561 - accuracy: 0.7762 - val_loss: 0.7100 - val_accuracy: 0.7615
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_48 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_49 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_16 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_27 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_50 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_51 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_17 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_28 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_11 (Flatten)        (None, 4096)              0
#
#  dense_23 (Dense)            (None, 512)               2097664
#
#  activation_52 (Activation)  (None, 512)               0
#
#  dropout_29 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 10)                5130
#
#  activation_53 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.5854 - accuracy: 0.4178
# Epoch 1: val_accuracy improved from -inf to 0.55410, saving model to best_model.Adam
# 1250/1250 [==============================] - 9s 5ms/step - loss: 1.5834 - accuracy: 0.4185 - val_loss: 1.2266 - val_accuracy: 0.5541
# Epoch 2/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.1517 - accuracy: 0.5903
# Epoch 2: val_accuracy improved from 0.55410 to 0.65350, saving model to best_model.Adam
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1507 - accuracy: 0.5903 - val_loss: 0.9613 - val_accuracy: 0.6535
# Epoch 3/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9888 - accuracy: 0.6485
# Epoch 3: val_accuracy improved from 0.65350 to 0.69560, saving model to best_model.Adam
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9888 - accuracy: 0.6485 - val_loss: 0.8450 - val_accuracy: 0.6956
# Epoch 4/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8860 - accuracy: 0.6890
# Epoch 4: val_accuracy improved from 0.69560 to 0.72220, saving model to best_model.Adam
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8860 - accuracy: 0.6891 - val_loss: 0.7831 - val_accuracy: 0.7222
# Epoch 5/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8111 - accuracy: 0.7139
# Epoch 5: val_accuracy improved from 0.72220 to 0.73170, saving model to best_model.Adam
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8111 - accuracy: 0.7139 - val_loss: 0.7635 - val_accuracy: 0.7317
# Epoch 6/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7486 - accuracy: 0.7370
# Epoch 6: val_accuracy improved from 0.73170 to 0.75570, saving model to best_model.Adam
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7490 - accuracy: 0.7368 - val_loss: 0.7041 - val_accuracy: 0.7557
# Epoch 7/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.7495
# Epoch 7: val_accuracy did not improve from 0.75570
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7066 - accuracy: 0.7495 - val_loss: 0.7192 - val_accuracy: 0.7493
# Epoch 8/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6591 - accuracy: 0.7686
# Epoch 8: val_accuracy did not improve from 0.75570
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6591 - accuracy: 0.7684 - val_loss: 0.7370 - val_accuracy: 0.7459
# Epoch 9/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6391 - accuracy: 0.7738
# Epoch 9: val_accuracy improved from 0.75570 to 0.76090, saving model to best_model.Adam
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6390 - accuracy: 0.7739 - val_loss: 0.6935 - val_accuracy: 0.7609
# Epoch 10/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6059 - accuracy: 0.7878
# Epoch 10: val_accuracy did not improve from 0.76090
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6059 - accuracy: 0.7878 - val_loss: 0.7185 - val_accuracy: 0.7519
# Epoch 11/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5718 - accuracy: 0.7969
# Epoch 11: val_accuracy did not improve from 0.76090
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5718 - accuracy: 0.7969 - val_loss: 0.7310 - val_accuracy: 0.7519
# Epoch 12/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.5436 - accuracy: 0.8086
# Epoch 12: val_accuracy improved from 0.76090 to 0.77860, saving model to best_model.Adam
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5434 - accuracy: 0.8086 - val_loss: 0.6682 - val_accuracy: 0.7786
# Epoch 13/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.5255 - accuracy: 0.8140
# Epoch 13: val_accuracy did not improve from 0.77860
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5255 - accuracy: 0.8140 - val_loss: 0.6861 - val_accuracy: 0.7708
# Epoch 14/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.5113 - accuracy: 0.8195
# Epoch 14: val_accuracy improved from 0.77860 to 0.78010, saving model to best_model.Adam
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5111 - accuracy: 0.8198 - val_loss: 0.6568 - val_accuracy: 0.7801
# Epoch 15/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.4915 - accuracy: 0.8275
# Epoch 15: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4916 - accuracy: 0.8275 - val_loss: 0.6706 - val_accuracy: 0.7756
# Epoch 16/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.4716 - accuracy: 0.8326
# Epoch 16: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4715 - accuracy: 0.8326 - val_loss: 0.7050 - val_accuracy: 0.7729
# Epoch 17/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 0.4571 - accuracy: 0.8383
# Epoch 17: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.4580 - accuracy: 0.8380 - val_loss: 0.6710 - val_accuracy: 0.7751
# Epoch 18/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.4479 - accuracy: 0.8410
# Epoch 18: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.4485 - accuracy: 0.8410 - val_loss: 0.6669 - val_accuracy: 0.7780
# Epoch 19/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.8474
# Epoch 19: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.4295 - accuracy: 0.8473 - val_loss: 0.6925 - val_accuracy: 0.7783
# Epoch 20/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.4248 - accuracy: 0.8489
# Epoch 20: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4250 - accuracy: 0.8489 - val_loss: 0.7020 - val_accuracy: 0.7739
# Epoch 21/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.4117 - accuracy: 0.8554
# Epoch 21: val_accuracy improved from 0.78010 to 0.78050, saving model to best_model.Adam
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.4116 - accuracy: 0.8552 - val_loss: 0.6922 - val_accuracy: 0.7805
# Epoch 22/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.4061 - accuracy: 0.8576
# Epoch 22: val_accuracy did not improve from 0.78050
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4057 - accuracy: 0.8577 - val_loss: 0.7384 - val_accuracy: 0.7730
# Epoch 23/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.3891 - accuracy: 0.8623
# Epoch 23: val_accuracy did not improve from 0.78050
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.3890 - accuracy: 0.8623 - val_loss: 0.7428 - val_accuracy: 0.7724
# Epoch 24/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.3875 - accuracy: 0.8644
# Epoch 24: val_accuracy did not improve from 0.78050
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.3874 - accuracy: 0.8644 - val_loss: 0.7230 - val_accuracy: 0.7733
# Epoch 25/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.3833 - accuracy: 0.8663
# Epoch 25: val_accuracy did not improve from 0.78050
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.3831 - accuracy: 0.8663 - val_loss: 0.6955 - val_accuracy: 0.7788
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_54 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_55 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_18 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_30 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_56 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_57 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_19 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_31 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_12 (Flatten)        (None, 4096)              0
#
#  dense_25 (Dense)            (None, 512)               2097664
#
#  activation_58 (Activation)  (None, 512)               0
#
#  dropout_32 (Dropout)        (None, 512)               0
#
#  dense_26 (Dense)            (None, 10)                5130
#
#  activation_59 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 2.2924 - accuracy: 0.1217
# Epoch 1: val_accuracy improved from -inf to 0.18180, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 8s 5ms/step - loss: 2.2923 - accuracy: 0.1217 - val_loss: 2.2610 - val_accuracy: 0.1818
# Epoch 2/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 2.1680 - accuracy: 0.1963
# Epoch 2: val_accuracy improved from 0.18180 to 0.27380, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.1672 - accuracy: 0.1967 - val_loss: 2.0192 - val_accuracy: 0.2738
# Epoch 3/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 2.0081 - accuracy: 0.2662
# Epoch 3: val_accuracy improved from 0.27380 to 0.30290, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 7s 5ms/step - loss: 2.0082 - accuracy: 0.2662 - val_loss: 1.9446 - val_accuracy: 0.3029
# Epoch 4/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.9367 - accuracy: 0.3006
# Epoch 4: val_accuracy improved from 0.30290 to 0.34020, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.9366 - accuracy: 0.3007 - val_loss: 1.8719 - val_accuracy: 0.3402
# Epoch 5/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.8719 - accuracy: 0.3271
# Epoch 5: val_accuracy improved from 0.34020 to 0.37090, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.8717 - accuracy: 0.3272 - val_loss: 1.7952 - val_accuracy: 0.3709
# Epoch 6/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.7980 - accuracy: 0.3582
# Epoch 6: val_accuracy improved from 0.37090 to 0.39530, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7980 - accuracy: 0.3583 - val_loss: 1.7252 - val_accuracy: 0.3953
# Epoch 7/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.7431 - accuracy: 0.3755
# Epoch 7: val_accuracy improved from 0.39530 to 0.40970, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7429 - accuracy: 0.3756 - val_loss: 1.6704 - val_accuracy: 0.4097
# Epoch 8/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.7007 - accuracy: 0.3898
# Epoch 8: val_accuracy improved from 0.40970 to 0.41780, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.7007 - accuracy: 0.3898 - val_loss: 1.6348 - val_accuracy: 0.4178
# Epoch 9/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.6670 - accuracy: 0.3997
# Epoch 9: val_accuracy improved from 0.41780 to 0.42210, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.6664 - accuracy: 0.4001 - val_loss: 1.6116 - val_accuracy: 0.4221
# Epoch 10/25
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.6463 - accuracy: 0.4050
# Epoch 10: val_accuracy improved from 0.42210 to 0.43830, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6456 - accuracy: 0.4057 - val_loss: 1.5835 - val_accuracy: 0.4383
# Epoch 11/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.6252 - accuracy: 0.4143
# Epoch 11: val_accuracy improved from 0.43830 to 0.44300, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6253 - accuracy: 0.4141 - val_loss: 1.5687 - val_accuracy: 0.4430
# Epoch 12/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.6057 - accuracy: 0.4195
# Epoch 12: val_accuracy improved from 0.44300 to 0.44680, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6062 - accuracy: 0.4191 - val_loss: 1.5531 - val_accuracy: 0.4468
# Epoch 13/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.5912 - accuracy: 0.4236
# Epoch 13: val_accuracy improved from 0.44680 to 0.45150, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5912 - accuracy: 0.4235 - val_loss: 1.5364 - val_accuracy: 0.4515
# Epoch 14/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.5774 - accuracy: 0.4300
# Epoch 14: val_accuracy improved from 0.45150 to 0.45980, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5773 - accuracy: 0.4299 - val_loss: 1.5228 - val_accuracy: 0.4598
# Epoch 15/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.5618 - accuracy: 0.4359
# Epoch 15: val_accuracy did not improve from 0.45980
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.5615 - accuracy: 0.4361 - val_loss: 1.5100 - val_accuracy: 0.4588
# Epoch 16/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.5492 - accuracy: 0.4414
# Epoch 16: val_accuracy improved from 0.45980 to 0.46680, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5489 - accuracy: 0.4413 - val_loss: 1.4944 - val_accuracy: 0.4668
# Epoch 17/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.5394 - accuracy: 0.4434
# Epoch 17: val_accuracy improved from 0.46680 to 0.47270, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5390 - accuracy: 0.4439 - val_loss: 1.4837 - val_accuracy: 0.4727
# Epoch 18/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.5313 - accuracy: 0.4478
# Epoch 18: val_accuracy improved from 0.47270 to 0.47310, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5307 - accuracy: 0.4481 - val_loss: 1.4789 - val_accuracy: 0.4731
# Epoch 19/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.5178 - accuracy: 0.4523
# Epoch 19: val_accuracy improved from 0.47310 to 0.47810, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5179 - accuracy: 0.4523 - val_loss: 1.4701 - val_accuracy: 0.4781
# Epoch 20/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.5089 - accuracy: 0.4554
# Epoch 20: val_accuracy improved from 0.47810 to 0.48260, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5095 - accuracy: 0.4553 - val_loss: 1.4569 - val_accuracy: 0.4826
# Epoch 21/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.4970 - accuracy: 0.4579
# Epoch 21: val_accuracy improved from 0.48260 to 0.48470, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4965 - accuracy: 0.4580 - val_loss: 1.4518 - val_accuracy: 0.4847
# Epoch 22/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.4882 - accuracy: 0.4645
# Epoch 22: val_accuracy improved from 0.48470 to 0.48860, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.4880 - accuracy: 0.4646 - val_loss: 1.4395 - val_accuracy: 0.4886
# Epoch 23/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.4768 - accuracy: 0.4688
# Epoch 23: val_accuracy improved from 0.48860 to 0.48880, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4772 - accuracy: 0.4687 - val_loss: 1.4299 - val_accuracy: 0.4888
# Epoch 24/25
# 1250/1250 [==============================] - ETA: 0s - loss: 1.4660 - accuracy: 0.4741
# Epoch 24: val_accuracy improved from 0.48880 to 0.49930, saving model to best_model.Adagrad
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4660 - accuracy: 0.4741 - val_loss: 1.4160 - val_accuracy: 0.4993
# Epoch 25/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.4586 - accuracy: 0.4706
# Epoch 25: val_accuracy did not improve from 0.49930
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4589 - accuracy: 0.4703 - val_loss: 1.4083 - val_accuracy: 0.4969
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7254 - accuracy: 0.7529
# Test accuracy for CNN + RMSprop optimizer: 0.7529000043869019
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7245 - accuracy: 0.7728
# Test accuracy for CNN + Adam optimizer: 0.7728000283241272
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3934 - accuracy: 0.5055
# Test accuracy for CNN + Adagrad optimizer: 0.5055000185966492

# %% [markdown]
# ### **b) Based on the above experiment answer the following [2.5x2 = 5 points]**
#
# 1. Rank the models in terms of performance on the training set?
#
# 2. Rank the models in terms of performance on the validation set?
#
#
# Provide your answers in the text box below.

# %% [markdown]
# ### **Answers**
#
# 1. In terms of training accuracy, Adam performs the best followed by RMSprop and then Adagrad.
#
# 2. In terms of validation set accuracy, Adam performs slightly better than RMSprop and Adagrad still lags behind.

# %% [markdown]
# ## **9. The effects of convolutional filters on the CNN [10 points]**
#
# ### **a) Compare the base CNN with 3x3 filters against a modified CNN with 5x5 filters [5 points]**
# The base CNN contains two stacks of **(CONV2D, Activation, CONV2D, Activation)** layers with **3x3 filters**. Create a modified CNN by replacing each of the bigger stacks with a smaller stack of **(CONV2D, Activation)** layers with **5x5 filters**. Do not change the output size in the smaller stack. Produce two graphs (one for training accuracy and the other one for validation accuracy) that each contain 2 curves (for 3x3 filters and 5x5 filters). The y-axis is the accuracy and the x-axis is the number of epochs. Produce curves for up to 25 epochs.
#
# *   The two graphs for training and validation accuracy.
# *   For each filter configuration, print the test accuracy of the model that achieved the best validation accuracy among all epochs (i.e., one best test accuracy per filter configuration).

# %%
def new_cnn():
  """
  TO-DO: Copy the code from the base_cnn() function above and paste it here.
  This started code has two stacks of (Conv2D, Activation, Conv2D, Activation)
  layers with 3x3 filters. Replace each such stack with a smaller stack of
  (Conv2D, Activation) layers with 5x5 filters. Do not change the output size of
  the the Conv2D filter. Any other parts of the code should remain unchanged.
  """
  model = Sequential()
  # stack 1
  model.add(Conv2D(32, (5, 5), padding='same',input_shape=x_train.shape[1:]))
  model.add(Activation('relu'))

  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  # stack 2
  model.add(Conv2D(64, (5, 5), padding='same'))
  model.add(Activation('relu'))

  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
  opt = keras.optimizers.RMSprop(learning_rate=0.0001, weight_decay=1e-6)
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print(model.summary())

  return model

  return model

# %% [markdown]
# ### Test code to simulate the scenario (**do not modify**)
#
# **Expected runtime on Google Colab:** 30-60 minutes with TPU/GPU resources

# %%
# create a callback that will save the best model while training
history_cnns = dict()

for cnn in ['base', 'new']:
  print('Training the {} CNN'.format(cnn))
  save_best_model = ModelCheckpoint('best_model.{}'.format(cnn), monitor='val_accuracy',
                                    mode='max', save_best_only=True, verbose=1)
  if cnn == 'base':
    model =  base_cnn()
  else:
    model = new_cnn()

  history_cnns[cnn] = model.fit(x_train, y_train,
                                batch_size=batch_size,
                                epochs=epochs,
                                validation_data=(x_validate, y_validate),
                                shuffle=True,
                                callbacks=[save_best_model])
# Plot training accuracy
plt.plot(history_cnns['base'].history['accuracy'], 'o-', label='CNN with 3X3 filters')
plt.plot(history_cnns['new'].history['accuracy'], 'o-', label='CNN with 5X5 filters')

plt.title('training accuracy')
plt.ylabel('training accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Plot validation accuracy
plt.plot(history_cnns['base'].history['val_accuracy'], 'o-', label='CNN with 3X3 filters')
plt.plot(history_cnns['new'].history['val_accuracy'], 'o-', label='CNN with 5X5 filters')

plt.title('validation accuracy')
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# Evaluate the best model saved (i.e., model with best validation accuracy) on the test set
for cnn in ['base', 'new']:
  saved_model = load_model('best_model.{}'.format(cnn))
  scores = saved_model.evaluate(x_test, y_test, verbose=1)
  print('Test accuracy for CNN with {} filters: {}'.format(('3X3', '5X5')[cnn=='new'], scores[1]))
# Out:
# Training the base CNN
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_60 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_61 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_20 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_33 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_42 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_62 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_63 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_21 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_34 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_13 (Flatten)        (None, 4096)              0
#
#  dense_27 (Dense)            (None, 512)               2097664
#
#  activation_64 (Activation)  (None, 512)               0
#
#  dropout_35 (Dropout)        (None, 512)               0
#
#  dense_28 (Dense)            (None, 10)                5130
#
#  activation_65 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.8793 - accuracy: 0.3163
# Epoch 1: val_accuracy improved from -inf to 0.43160, saving model to best_model.base
# 1250/1250 [==============================] - 9s 6ms/step - loss: 1.8776 - accuracy: 0.3169 - val_loss: 1.5874 - val_accuracy: 0.4316
# Epoch 2/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.5432 - accuracy: 0.4415
# Epoch 2: val_accuracy improved from 0.43160 to 0.49940, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5430 - accuracy: 0.4417 - val_loss: 1.4013 - val_accuracy: 0.4994
# Epoch 3/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3864 - accuracy: 0.4989
# Epoch 3: val_accuracy improved from 0.49940 to 0.54960, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3865 - accuracy: 0.4989 - val_loss: 1.2729 - val_accuracy: 0.5496
# Epoch 4/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.2863 - accuracy: 0.5405
# Epoch 4: val_accuracy improved from 0.54960 to 0.58490, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2858 - accuracy: 0.5407 - val_loss: 1.1830 - val_accuracy: 0.5849
# Epoch 5/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.2018 - accuracy: 0.5761
# Epoch 5: val_accuracy improved from 0.58490 to 0.60590, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2021 - accuracy: 0.5760 - val_loss: 1.1164 - val_accuracy: 0.6059
# Epoch 6/25
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.1309 - accuracy: 0.5979
# Epoch 6: val_accuracy improved from 0.60590 to 0.62370, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1309 - accuracy: 0.5982 - val_loss: 1.0698 - val_accuracy: 0.6237
# Epoch 7/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.0707 - accuracy: 0.6219
# Epoch 7: val_accuracy improved from 0.62370 to 0.64480, saving model to best_model.base
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.0701 - accuracy: 0.6221 - val_loss: 1.0190 - val_accuracy: 0.6448
# Epoch 8/25
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.0197 - accuracy: 0.6403
# Epoch 8: val_accuracy improved from 0.64480 to 0.66230, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0197 - accuracy: 0.6401 - val_loss: 0.9616 - val_accuracy: 0.6623
# Epoch 9/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9818 - accuracy: 0.6542
# Epoch 9: val_accuracy improved from 0.66230 to 0.67230, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9815 - accuracy: 0.6542 - val_loss: 0.9287 - val_accuracy: 0.6723
# Epoch 10/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.9415 - accuracy: 0.6701
# Epoch 10: val_accuracy improved from 0.67230 to 0.68510, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9407 - accuracy: 0.6702 - val_loss: 0.8975 - val_accuracy: 0.6851
# Epoch 11/25
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.9055 - accuracy: 0.6818
# Epoch 11: val_accuracy improved from 0.68510 to 0.70180, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9063 - accuracy: 0.6818 - val_loss: 0.8643 - val_accuracy: 0.7018
# Epoch 12/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8796 - accuracy: 0.6906
# Epoch 12: val_accuracy improved from 0.70180 to 0.70220, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8795 - accuracy: 0.6906 - val_loss: 0.8507 - val_accuracy: 0.7022
# Epoch 13/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.8542 - accuracy: 0.7020
# Epoch 13: val_accuracy did not improve from 0.70220
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8538 - accuracy: 0.7021 - val_loss: 0.8516 - val_accuracy: 0.7008
# Epoch 14/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8346 - accuracy: 0.7078
# Epoch 14: val_accuracy improved from 0.70220 to 0.71090, saving model to best_model.base
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8343 - accuracy: 0.7079 - val_loss: 0.8261 - val_accuracy: 0.7109
# Epoch 15/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8061 - accuracy: 0.7178
# Epoch 15: val_accuracy did not improve from 0.71090
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.8063 - accuracy: 0.7176 - val_loss: 0.8333 - val_accuracy: 0.7093
# Epoch 16/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7877 - accuracy: 0.7265
# Epoch 16: val_accuracy improved from 0.71090 to 0.73040, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7875 - accuracy: 0.7266 - val_loss: 0.7846 - val_accuracy: 0.7304
# Epoch 17/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.7749 - accuracy: 0.7304
# Epoch 17: val_accuracy improved from 0.73040 to 0.73410, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7759 - accuracy: 0.7301 - val_loss: 0.7737 - val_accuracy: 0.7341
# Epoch 18/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7592 - accuracy: 0.7349
# Epoch 18: val_accuracy improved from 0.73410 to 0.73850, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7591 - accuracy: 0.7350 - val_loss: 0.7541 - val_accuracy: 0.7385
# Epoch 19/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.7457 - accuracy: 0.7449
# Epoch 19: val_accuracy did not improve from 0.73850
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7450 - accuracy: 0.7448 - val_loss: 0.7914 - val_accuracy: 0.7275
# Epoch 20/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.7315 - accuracy: 0.7456
# Epoch 20: val_accuracy did not improve from 0.73850
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7307 - accuracy: 0.7459 - val_loss: 0.7906 - val_accuracy: 0.7319
# Epoch 21/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7215 - accuracy: 0.7518
# Epoch 21: val_accuracy improved from 0.73850 to 0.74520, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7212 - accuracy: 0.7519 - val_loss: 0.7424 - val_accuracy: 0.7452
# Epoch 22/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.7584
# Epoch 22: val_accuracy did not improve from 0.74520
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7056 - accuracy: 0.7584 - val_loss: 0.7635 - val_accuracy: 0.7409
# Epoch 23/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6977 - accuracy: 0.7607
# Epoch 23: val_accuracy improved from 0.74520 to 0.75500, saving model to best_model.base
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6977 - accuracy: 0.7606 - val_loss: 0.7229 - val_accuracy: 0.7550
# Epoch 24/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6927 - accuracy: 0.7626
# Epoch 24: val_accuracy did not improve from 0.75500
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6926 - accuracy: 0.7625 - val_loss: 0.7437 - val_accuracy: 0.7525
# Epoch 25/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6832 - accuracy: 0.7665
# Epoch 25: val_accuracy did not improve from 0.75500
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6834 - accuracy: 0.7664 - val_loss: 0.7551 - val_accuracy: 0.7475
# Training the new CNN
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_44 (Conv2D)          (None, 32, 32, 32)        2432
#
#  activation_66 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_22 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  dropout_36 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_45 (Conv2D)          (None, 16, 16, 64)        51264
#
#  activation_67 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_23 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_37 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_14 (Flatten)        (None, 4096)              0
#
#  dense_29 (Dense)            (None, 512)               2097664
#
#  activation_68 (Activation)  (None, 512)               0
#
#  dropout_38 (Dropout)        (None, 512)               0
#
#  dense_30 (Dense)            (None, 10)                5130
#
#  activation_69 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 2156490 (8.23 MB)
# Trainable params: 2156490 (8.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.8726 - accuracy: 0.3196
# Epoch 1: val_accuracy improved from -inf to 0.41420, saving model to best_model.new
# 1250/1250 [==============================] - 8s 5ms/step - loss: 1.8698 - accuracy: 0.3206 - val_loss: 1.6310 - val_accuracy: 0.4142
# Epoch 2/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.5454 - accuracy: 0.4476
# Epoch 2: val_accuracy improved from 0.41420 to 0.51480, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.5454 - accuracy: 0.4476 - val_loss: 1.4277 - val_accuracy: 0.5148
# Epoch 3/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.4124 - accuracy: 0.4956
# Epoch 3: val_accuracy improved from 0.51480 to 0.54340, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4125 - accuracy: 0.4954 - val_loss: 1.3351 - val_accuracy: 0.5434
# Epoch 4/25
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3196 - accuracy: 0.5316
# Epoch 4: val_accuracy improved from 0.54340 to 0.56380, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3196 - accuracy: 0.5316 - val_loss: 1.2510 - val_accuracy: 0.5638
# Epoch 5/25
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.2467 - accuracy: 0.5584
# Epoch 5: val_accuracy improved from 0.56380 to 0.59590, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2463 - accuracy: 0.5588 - val_loss: 1.1747 - val_accuracy: 0.5959
# Epoch 6/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.1827 - accuracy: 0.5813
# Epoch 6: val_accuracy improved from 0.59590 to 0.62160, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1829 - accuracy: 0.5812 - val_loss: 1.1294 - val_accuracy: 0.6216
# Epoch 7/25
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1292 - accuracy: 0.6031
# Epoch 7: val_accuracy improved from 0.62160 to 0.62460, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1295 - accuracy: 0.6029 - val_loss: 1.0991 - val_accuracy: 0.6246
# Epoch 8/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0913 - accuracy: 0.6174
# Epoch 8: val_accuracy improved from 0.62460 to 0.63940, saving model to best_model.new
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0916 - accuracy: 0.6173 - val_loss: 1.0512 - val_accuracy: 0.6394
# Epoch 9/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.0506 - accuracy: 0.6339
# Epoch 9: val_accuracy improved from 0.63940 to 0.64700, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0512 - accuracy: 0.6338 - val_loss: 1.0269 - val_accuracy: 0.6470
# Epoch 10/25
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.0189 - accuracy: 0.6427
# Epoch 10: val_accuracy improved from 0.64700 to 0.66940, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0187 - accuracy: 0.6429 - val_loss: 0.9694 - val_accuracy: 0.6694
# Epoch 11/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.9855 - accuracy: 0.6574
# Epoch 11: val_accuracy did not improve from 0.66940
# 1250/1250 [==============================] - 4s 4ms/step - loss: 0.9858 - accuracy: 0.6573 - val_loss: 0.9652 - val_accuracy: 0.6659
# Epoch 12/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9647 - accuracy: 0.6654
# Epoch 12: val_accuracy improved from 0.66940 to 0.68100, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9647 - accuracy: 0.6654 - val_loss: 0.9352 - val_accuracy: 0.6810
# Epoch 13/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.9416 - accuracy: 0.6747
# Epoch 13: val_accuracy improved from 0.68100 to 0.68940, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9424 - accuracy: 0.6740 - val_loss: 0.9266 - val_accuracy: 0.6894
# Epoch 14/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.9201 - accuracy: 0.6810
# Epoch 14: val_accuracy improved from 0.68940 to 0.69120, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9201 - accuracy: 0.6812 - val_loss: 0.9101 - val_accuracy: 0.6912
# Epoch 15/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.9043 - accuracy: 0.6872
# Epoch 15: val_accuracy improved from 0.69120 to 0.69500, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9039 - accuracy: 0.6875 - val_loss: 0.8948 - val_accuracy: 0.6950
# Epoch 16/25
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8825 - accuracy: 0.6966
# Epoch 16: val_accuracy did not improve from 0.69500
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8831 - accuracy: 0.6963 - val_loss: 0.9172 - val_accuracy: 0.6942
# Epoch 17/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8700 - accuracy: 0.6978
# Epoch 17: val_accuracy improved from 0.69500 to 0.70770, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8705 - accuracy: 0.6976 - val_loss: 0.8882 - val_accuracy: 0.7077
# Epoch 18/25
# 1235/1250 [============================>.] - ETA: 0s - loss: 0.8514 - accuracy: 0.7048
# Epoch 18: val_accuracy did not improve from 0.70770
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8520 - accuracy: 0.7047 - val_loss: 0.8924 - val_accuracy: 0.6995
# Epoch 19/25
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.8393 - accuracy: 0.7108
# Epoch 19: val_accuracy improved from 0.70770 to 0.71400, saving model to best_model.new
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8393 - accuracy: 0.7106 - val_loss: 0.8757 - val_accuracy: 0.7140
# Epoch 20/25
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8275 - accuracy: 0.7175
# Epoch 20: val_accuracy did not improve from 0.71400
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8275 - accuracy: 0.7175 - val_loss: 0.8764 - val_accuracy: 0.7051
# Epoch 21/25
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.8159 - accuracy: 0.7207
# Epoch 21: val_accuracy improved from 0.71400 to 0.72050, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8154 - accuracy: 0.7207 - val_loss: 0.8809 - val_accuracy: 0.7205
# Epoch 22/25
# 1237/1250 [============================>.] - ETA: 0s - loss: 0.8033 - accuracy: 0.7259
# Epoch 22: val_accuracy improved from 0.72050 to 0.72640, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8040 - accuracy: 0.7257 - val_loss: 0.8432 - val_accuracy: 0.7264
# Epoch 23/25
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7959 - accuracy: 0.7270
# Epoch 23: val_accuracy improved from 0.72640 to 0.72840, saving model to best_model.new
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7959 - accuracy: 0.7269 - val_loss: 0.8337 - val_accuracy: 0.7284
# Epoch 24/25
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7876 - accuracy: 0.7301
# Epoch 24: val_accuracy did not improve from 0.72840
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7877 - accuracy: 0.7300 - val_loss: 0.8675 - val_accuracy: 0.7211
# Epoch 25/25
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.7749 - accuracy: 0.7356
# Epoch 25: val_accuracy did not improve from 0.72840
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7744 - accuracy: 0.7358 - val_loss: 0.8280 - val_accuracy: 0.7268
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7364 - accuracy: 0.7494
# Test accuracy for CNN with 3X3 filters: 0.7494000196456909
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8436 - accuracy: 0.7173
# Test accuracy for CNN with 5X5 filters: 0.7172999978065491

# %% [markdown]
# ### **b) Based on the above experiment answer the following [2.5X2 = 5 points]**
#
# 1. Rank the models (CNN with 3x3 filter and CNN with 5x5 filter) on the training and validation datasets.
#
# 2. Which model learns **better** intermediate representations of the images as information flows through the neural network? Better intermediate representations lead to better model performance.
#
#
# Provide your answers in the text box below.

# %% [markdown]
# ### **Answers**
#
# 1. As evident from the graphs, CNN with 3x3 filters is better than CNN with 5x5 filters on both training and validation datasets.
#
# 2. CNN with 3x3 filters learns better intermediate representations because although 5x5 filters capture more context per layer but number of nonlinear transformations are reduced and also they 5x5 filters are more coarse grained compared to 3x3 filters which capture more fine-grained context.

# %% [markdown]
# ## **10. Acknowledgement**
#
# Parts of this assignment are adapted from the Machine Learning course previously offered at the University of Waterloo. We recalibrated the scope and content, performed extensive code modifications and performance optimization.
